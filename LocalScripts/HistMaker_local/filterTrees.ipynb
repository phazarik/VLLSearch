# %% [markdown]
# # Python based analysis
#
# This script takes trees as inputs and writes another sets of trees as outputs.<br>
# The trees are filtered in between.

# %%
import os, sys
import numpy as np
import uproot
import pandas as pd

# %%
#Global parameters

basedir = '../input_files/trees_modified'
injob  = 'tree_2016preVFPUL_baseline_Jan02'
outjob = 'tree_2016preVFPUL_topcr_Jan02'
campaign = '2016preVFP_UL'

indir = os.path.join(basedir, injob)
outdir = os.path.join(basedir, outjob)
os.makedirs(outdir, exist_ok=True)

# %%
def read_file_into_df(filepath):

    tfile = uproot.open(filepath)
    ttree = tfile['myEvents']
    branches = ttree.keys()
    awkarray = ttree.arrays(branches)
    df = pd.DataFrame(awkarray.to_list())

    #Not filtering by channels right now.
    #if 'channel' in df.columns: df = df[df['channel'] == channelno]       
    #print(f'dataframe for {sample} {subsample} loaded.')
    return df

def write_df_into_file(df, filepath):
    if df.empty:
        data_dict = {col: np.array([], dtype=df[col].dtype) for col in df.columns}
        print(f"\033[0;31mWarning: Writing empty file: {filepath}\033[0m\n")
    else:
        data_dict = df.to_dict('list')
        
    with uproot.recreate(filepath) as file: file['myEvents'] = data_dict
    
print('Functions loaded.')
# Out:
# Functions loaded.

# %%
# %%time

list_of_files = os.listdir(indir)
list_empty_input = []
list_empty_output = []

for f in list_of_files:

    #if 'SingleMuon' not in f: continue

    #Step1: Prepare the dataframe
    print(f'\nLoading file: {f}')
    filepath = os.path.join(indir, f)
    sample = f.split("_")[1]
    subsample = "_".join(f.split("_")[2:])
       
    outfile = os.path.join(outdir, f)
    #if os.path.exists(outfile): continue
    #if 'WJets' not in f: continue

    df = read_file_into_df(filepath)
    if df.empty : 
        print(f"\033[0;31mWarning: Empty input file: {filepath}\033[0m\n")
        list_empty_input.append(filepath)

    #Creating working points on the dataframe using the NN.
    df['flag_qcd'] = (
        ((df['channel'].isin([0, 1])) & (df['nnscore_qcd_vlldmu_200_800']  < 0.30)) |
        ((df['channel'].isin([2, 3])) & (df['nnscore_qcd_vlldele_200_800'] < 0.30))
    )

    df['flag_topregion'] = (
        ((df['channel'].isin([0, 1])) & (df['nnscore_qcd_vlldmu_200_800']  > 0.50) & (df['nnscore_qcd_vlldmu_200_800']  < 0.70)) |
        ((df['channel'].isin([2, 3])) & (df['nnscore_qcd_vlldmu_200_800']  > 0.50) & (df['nnscore_qcd_vlldele_200_800'] < 0.70))
    )
    
    df['flag_searchregion'] = (
        ((df['channel'].isin([0, 1])) & (df['nnscore_qcd_vlldmu_200_800']  > 0.70)) |
        ((df['channel'].isin([2, 3])) & (df['nnscore_qcd_vlldele_200_800'] > 0.70))
    )

    # Put any cuts here on dataframe as you like
    # Define conditions as strings
    dy_veto = 'not (channel == 3 and 76 < dilep_mass < 106)'

    #Step1: Controlling QCD:
    qcd_cr = f'{dy_veto} and flag_qcd and 0.02<lep0_iso<0.15 and lep0_sip3d>5'
    qcd_vr = f'{dy_veto} and flag_qcd and 0.02<lep0_iso<0.15 and lep0_sip3d<5'

    #Step2: Controlling Drell-Yan:
    dycr  = f'76<dilep_mass<106  and dilep_ptratio > 0.7'

    tight_sip3d =  'lep0_sip3d<5 and lep1_sip3d<10'
    qcd_veto = f'{tight_sip3d} and {dy_veto} and not flag_qcd and HT>50'

    #Step3: Controlling TTbar:
    top_cr = f'{qcd_veto} and flag_topregion'
    top_vr = f'{qcd_veto} and flag_searchregion and nbjet>0'

    #Step5: Signal regions:
    sig_region = f'{qcd_veto} and flag_searchregion and nbjet == 0'
    
    #------------------------------
    # Final event selection:
    event_selection = top_cr
    #------------------------------

    # Use df.query with the combined condition
    df_filtered = df.query(event_selection)
    
    if df_filtered.empty: list_empty_output.append(f'{sample}_{subsample}')

    nbefore = len(df)
    nafter = len(df_filtered)

    frac = 0
    if nbefore != 0: frac = nafter*100/nbefore

    #display(df_filtered)

    write_df_into_file(df_filtered, outfile)
    print(f'\033[1;32mFile written: {outfile}\033[0m ({nbefore}->{nafter}, {frac:.2f}%)\n')
    #break #file

print(f'\n\033[1;33mSummary:\033[0m')
print(f'\n\033[33mEmpty input: {list_empty_input}\033[0m')
print(f'\n\033[31mEmpty output: {list_empty_output}\033[0m\n')
# Out:
# Loading file: tree_DYJetsToLL_M10to50.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_DYJetsToLL_M10to50.root (550->1, 0.18%)
#
#
# Loading file: tree_DYJetsToLL_M50.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_DYJetsToLL_M50.root (116397->88, 0.08%)
#
#
# Loading file: tree_EGamma_EGamma_B.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_EGamma_EGamma_B.root (42696->66, 0.15%)
#
#
# Loading file: tree_EGamma_EGamma_C.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_EGamma_EGamma_C.root (18737->40, 0.21%)
#
#
# Loading file: tree_EGamma_EGamma_D.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_EGamma_EGamma_D.root (30309->49, 0.16%)
#
#
# Loading file: tree_EGamma_EGamma_E.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_EGamma_EGamma_E.root (27737->53, 0.19%)
#
#
# Loading file: tree_EGamma_EGamma_F.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_EGamma_EGamma_F.root (18036->35, 0.19%)
#
#
# Loading file: tree_Higgs_bbH_HToZZTo4L.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_Higgs_bbH_HToZZTo4L.root (7697->35, 0.45%)
#
#
# Loading file: tree_Higgs_GluGluHToZZTo4L.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_Higgs_GluGluHToZZTo4L.root (18637->80, 0.43%)
#
#
# Loading file: tree_Higgs_GluGluToZH_HToZZTo4L.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_Higgs_GluGluToZH_HToZZTo4L.root (26857->672, 2.50%)
#
#
# Loading file: tree_Higgs_GluGluZH_HToWW_ZTo2L.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_Higgs_GluGluZH_HToWW_ZTo2L.root (6090->228, 3.74%)
#
#
# Loading file: tree_Higgs_ttHToNonbb.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_Higgs_ttHToNonbb.root (19554->1463, 7.48%)
#
#
# Loading file: tree_Higgs_VBF_HToZZTo4L.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_Higgs_VBF_HToZZTo4L.root (3936->53, 1.35%)
#
#
# Loading file: tree_Higgs_VHToNonbb.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_Higgs_VHToNonbb.root (2743->91, 3.32%)
#
#
# Loading file: tree_HTbinnedWJets_100to200.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_HTbinnedWJets_100to200.root (2516->54, 2.15%)
#
#
# Loading file: tree_HTbinnedWJets_1200to2500.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_HTbinnedWJets_1200to2500.root (226->2, 0.88%)
#
#
# Loading file: tree_HTbinnedWJets_200to400.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_HTbinnedWJets_200to400.root (3013->139, 4.61%)
#
#
# Loading file: tree_HTbinnedWJets_2500toInf.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_HTbinnedWJets_2500toInf.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_HTbinnedWJets_2500toInf.root (157->0, 0.00%)
#
#
# Loading file: tree_HTbinnedWJets_400to600.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_HTbinnedWJets_400to600.root (423->18, 4.26%)
#
#
# Loading file: tree_HTbinnedWJets_600to800.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_HTbinnedWJets_600to800.root (617->23, 3.73%)
#
#
# Loading file: tree_HTbinnedWJets_70to100.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_HTbinnedWJets_70to100.root (1473->11, 0.75%)
#
#
# Loading file: tree_HTbinnedWJets_800to1200.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_HTbinnedWJets_800to1200.root (705->21, 2.98%)
#
#
# Loading file: tree_QCD_EMEnriched_120to170.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_EMEnriched_120to170.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_EMEnriched_120to170.root (1->0, 0.00%)
#
#
# Loading file: tree_QCD_EMEnriched_170to300.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_EMEnriched_170to300.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_EMEnriched_170to300.root (6->0, 0.00%)
#
#
# Loading file: tree_QCD_EMEnriched_300toInf.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_EMEnriched_300toInf.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_EMEnriched_300toInf.root (1->0, 0.00%)
#
#
# Loading file: tree_QCD_EMEnriched_30to50.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_EMEnriched_30to50.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_EMEnriched_30to50.root (1->0, 0.00%)
#
#
# Loading file: tree_QCD_EMEnriched_80to120.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_EMEnriched_80to120.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_EMEnriched_80to120.root (2->0, 0.00%)
#
#
# Loading file: tree_QCD_MuEnriched_120to170.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_MuEnriched_120to170.root (109->1, 0.92%)
#
#
# Loading file: tree_QCD_MuEnriched_170to300.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_MuEnriched_170to300.root (177->1, 0.56%)
#
#
# Loading file: tree_QCD_MuEnriched_20to30.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_MuEnriched_20to30.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_MuEnriched_20to30.root (3->0, 0.00%)
#
#
# Loading file: tree_QCD_MuEnriched_300to470.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_MuEnriched_300to470.root (131->3, 2.29%)
#
#
# Loading file: tree_QCD_MuEnriched_30to50.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_MuEnriched_30to50.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_MuEnriched_30to50.root (25->0, 0.00%)
#
#
# Loading file: tree_QCD_MuEnriched_470to600.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_MuEnriched_470to600.root (79->1, 1.27%)
#
#
# Loading file: tree_QCD_MuEnriched_50to80.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_MuEnriched_50to80.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_MuEnriched_50to80.root (81->0, 0.00%)
#
#
# Loading file: tree_QCD_MuEnriched_600to800.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_MuEnriched_600to800.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_MuEnriched_600to800.root (58->0, 0.00%)
#
#
# Loading file: tree_QCD_MuEnriched_800to1000.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_MuEnriched_800to1000.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_MuEnriched_800to1000.root (141->0, 0.00%)
#
#
# Loading file: tree_QCD_MuEnriched_80to120.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_MuEnriched_80to120.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_QCD_MuEnriched_80to120.root (123->0, 0.00%)
#
#
# Loading file: tree_Rare_THQ.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_Rare_THQ.root (6476->372, 5.74%)
#
#
# Loading file: tree_Rare_THW.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_Rare_THW.root (3972->320, 8.06%)
#
#
# Loading file: tree_Rare_TTHH.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_Rare_TTHH.root (918->63, 6.86%)
#
#
# Loading file: tree_Rare_TTTJ.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_Rare_TTTJ.root (1343->115, 8.56%)
#
#
# Loading file: tree_Rare_TTTT.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_Rare_TTTT.root (26125->2091, 8.00%)
#
#
# Loading file: tree_Rare_TTTW.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_Rare_TTTW.root (2087->170, 8.15%)
#
#
# Loading file: tree_Rare_TTWH.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_Rare_TTWH.root (1760->126, 7.16%)
#
#
# Loading file: tree_Rare_TTWW.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_Rare_TTWW.root (5017->396, 7.89%)
#
#
# Loading file: tree_Rare_TTWZ.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_Rare_TTWZ.root (1857->130, 7.00%)
#
#
# Loading file: tree_Rare_TTZH.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_Rare_TTZH.root (832->49, 5.89%)
#
#
# Loading file: tree_Rare_TTZZ.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_Rare_TTZZ.root (672->41, 6.10%)
#
#
# Loading file: tree_Rare_tZq_ll.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_Rare_tZq_ll.root (61435->2856, 4.65%)
#
#
# Loading file: tree_SingleMuon_SingleMuon_B.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_SingleMuon_SingleMuon_B.root (11057->218, 1.97%)
#
#
# Loading file: tree_SingleMuon_SingleMuon_C.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_SingleMuon_SingleMuon_C.root (4819->100, 2.08%)
#
#
# Loading file: tree_SingleMuon_SingleMuon_D.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_SingleMuon_SingleMuon_D.root (7924->156, 1.97%)
#
#
# Loading file: tree_SingleMuon_SingleMuon_E.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_SingleMuon_SingleMuon_E.root (7573->141, 1.86%)
#
#
# Loading file: tree_SingleMuon_SingleMuon_F.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_SingleMuon_SingleMuon_F.root (5122->91, 1.78%)
#
#
# Loading file: tree_SingleTop_s-channel_LeptonDecays.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_SingleTop_s-channel_LeptonDecays.root (6983->156, 2.23%)
#
#
# Loading file: tree_SingleTop_t-channel_AntiTop_InclusiveDecays.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_SingleTop_t-channel_AntiTop_InclusiveDecays.root (7797->182, 2.33%)
#
#
# Loading file: tree_SingleTop_t-channel_Top_InclusiveDecays.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_SingleTop_t-channel_Top_InclusiveDecays.root (17968->466, 2.59%)
#
#
# Loading file: tree_SingleTop_tW_AntiTop_InclusiveDecays.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_SingleTop_tW_AntiTop_InclusiveDecays.root (1904->74, 3.89%)
#
#
# Loading file: tree_SingleTop_tW_Top_InclusiveDecays.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_SingleTop_tW_Top_InclusiveDecays.root (2071->72, 3.48%)
#
#
# Loading file: tree_TTBar_TTTo2L2Nu.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_TTBar_TTTo2L2Nu.root (121998->4500, 3.69%)
#
#
# Loading file: tree_TTBar_TTToSemiLeptonic.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_TTBar_TTToSemiLeptonic.root (192565->9193, 4.77%)
#
#
# Loading file: tree_TTW_TTWToLNu.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_TTW_TTWToLNu.root (176886->13027, 7.36%)
#
#
# Loading file: tree_TTZ_TTZToLL.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_TTZ_TTZToLL.root (738166->48247, 6.54%)
#
#
# Loading file: tree_VLLD_ele_M100.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLD_ele_M100.root (3015->98, 3.25%)
#
#
# Loading file: tree_VLLD_ele_M1000.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLD_ele_M1000.root (1128->23, 2.04%)
#
#
# Loading file: tree_VLLD_ele_M200.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLD_ele_M200.root (3218->93, 2.89%)
#
#
# Loading file: tree_VLLD_ele_M300.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLD_ele_M300.root (1065->28, 2.63%)
#
#
# Loading file: tree_VLLD_ele_M400.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLD_ele_M400.root (1089->18, 1.65%)
#
#
# Loading file: tree_VLLD_ele_M600.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLD_ele_M600.root (1117->23, 2.06%)
#
#
# Loading file: tree_VLLD_ele_M800.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLD_ele_M800.root (1088->18, 1.65%)
#
#
# Loading file: tree_VLLD_mu_M100.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLD_mu_M100.root (3185->140, 4.40%)
#
#
# Loading file: tree_VLLD_mu_M200.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLD_mu_M200.root (1870->126, 6.74%)
#
#
# Loading file: tree_VLLD_mu_M300.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLD_mu_M300.root (562->23, 4.09%)
#
#
# Loading file: tree_VLLD_mu_M400.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLD_mu_M400.root (518->36, 6.95%)
#
#
# Loading file: tree_VLLD_mu_M600.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLD_mu_M600.root (473->22, 4.65%)
#
#
# Loading file: tree_VLLD_mu_M800.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLD_mu_M800.root (454->26, 5.73%)
#
#
# Loading file: tree_VLLS_ele_M100.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_ele_M100.root (835->15, 1.80%)
#
#
# Loading file: tree_VLLS_ele_M1000.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_ele_M1000.root (1218->15, 1.23%)
#
#
# Loading file: tree_VLLS_ele_M125.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_ele_M125.root (3362->75, 2.23%)
#
#
# Loading file: tree_VLLS_ele_M150.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_ele_M150.root (4713->101, 2.14%)
#
#
# Loading file: tree_VLLS_ele_M200.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_ele_M200.root (5965->133, 2.23%)
#
#
# Loading file: tree_VLLS_ele_M250.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_ele_M250.root (5238->90, 1.72%)
#
#
# Loading file: tree_VLLS_ele_M300.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_ele_M300.root (5538->90, 1.63%)
#
#
# Loading file: tree_VLLS_ele_M350.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_ele_M350.root (2259->35, 1.55%)
#
#
# Loading file: tree_VLLS_ele_M400.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_ele_M400.root (2402->44, 1.83%)
#
#
# Loading file: tree_VLLS_ele_M450.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_ele_M450.root (2343->32, 1.37%)
#
#
# Loading file: tree_VLLS_ele_M500.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_ele_M500.root (2356->37, 1.57%)
#
#
# Loading file: tree_VLLS_ele_M750.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_ele_M750.root (1212->15, 1.24%)
#
#
# Loading file: tree_VLLS_mu_M100.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_mu_M100.root (879->19, 2.16%)
#
#
# Loading file: tree_VLLS_mu_M1000.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_mu_M1000.root (718->14, 1.95%)
#
#
# Loading file: tree_VLLS_mu_M125.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_mu_M125.root (3755->126, 3.36%)
#
#
# Loading file: tree_VLLS_mu_M150.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_mu_M150.root (4398->207, 4.71%)
#
#
# Loading file: tree_VLLS_mu_M200.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_mu_M200.root (5087->305, 6.00%)
#
#
# Loading file: tree_VLLS_mu_M250.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_mu_M250.root (4320->253, 5.86%)
#
#
# Loading file: tree_VLLS_mu_M300.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_mu_M300.root (4460->221, 4.96%)
#
#
# Loading file: tree_VLLS_mu_M400.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_mu_M400.root (1722->63, 3.66%)
#
#
# Loading file: tree_VLLS_mu_M450.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_mu_M450.root (1648->52, 3.16%)
#
#
# Loading file: tree_VLLS_mu_M500.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_mu_M500.root (1668->61, 3.66%)
#
#
# Loading file: tree_VLLS_mu_M750.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_mu_M750.root (841->27, 3.21%)
#
#
# Loading file: tree_VLLS_tau_M100.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_tau_M100.root (1137->10, 0.88%)
#
#
# Loading file: tree_VLLS_tau_M125.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_tau_M125.root (2890->62, 2.15%)
#
#
# Loading file: tree_VLLS_tau_M150.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_tau_M150.root (3883->113, 2.91%)
#
#
# Loading file: tree_VLLS_tau_M200.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_tau_M200.root (5001->212, 4.24%)
#
#
# Loading file: tree_VLLS_tau_M250.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_tau_M250.root (4539->197, 4.34%)
#
#
# Loading file: tree_VLLS_tau_M300.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_tau_M300.root (4972->182, 3.66%)
#
#
# Loading file: tree_VLLS_tau_M350.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_tau_M350.root (2022->60, 2.97%)
#
#
# Loading file: tree_VLLS_tau_M400.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_VLLS_tau_M400.root (2144->85, 3.96%)
#
#
# Loading file: tree_WGamma_WGToLNuG_01J.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_WGamma_WGToLNuG_01J.root (90029->1436, 1.60%)
#
#
# Loading file: tree_WpWp_WpWpJJEWK.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_WpWp_WpWpJJEWK.root (16890->913, 5.41%)
#
#
# Loading file: tree_WWW_Inclusive.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_WWW_Inclusive.root (952->53, 5.57%)
#
#
# Loading file: tree_WWZ_Inclusive.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_WWZ_Inclusive.root (286->9, 3.15%)
#
#
# Loading file: tree_WW_WWTo1L1Nu2Q.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_WW_WWTo1L1Nu2Q.root (3036->88, 2.90%)
#
#
# Loading file: tree_WW_WWTo2L2Nu.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_WW_WWTo2L2Nu.root (5288->54, 1.02%)
#
#
# Loading file: tree_WW_WWTo4Q.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_WW_WWTo4Q.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_WW_WWTo4Q.root (8->0, 0.00%)
#
#
# Loading file: tree_WZZ_Inclusive.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_WZZ_Inclusive.root (658->28, 4.26%)
#
#
# Loading file: tree_WZ_WZTo1L1Nu2Q.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_WZ_WZTo1L1Nu2Q.root (753->20, 2.66%)
#
#
# Loading file: tree_WZ_WZTo2L2Q.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_WZ_WZTo2L2Q.root (21719->69, 0.32%)
#
#
# Loading file: tree_WZ_WZTo3LNu.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_WZ_WZTo3LNu.root (344190->9124, 2.65%)
#
#
# Loading file: tree_ZGamma_ZGToLLG_01J.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_ZGamma_ZGToLLG_01J.root (63453->205, 0.32%)
#
#
# Loading file: tree_ZZZ_Inclusive.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_ZZZ_Inclusive.root (119->5, 4.20%)
#
#
# Loading file: tree_ZZ_ZZTo2L2Nu.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_ZZ_ZZTo2L2Nu.root (22945->24, 0.10%)
#
#
# Loading file: tree_ZZ_ZZTo2Q2L.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_ZZ_ZZTo2Q2L.root (26501->111, 0.42%)
#
#
# Loading file: tree_ZZ_ZZTo2Q2Nu.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_ZZ_ZZTo2Q2Nu.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_ZZ_ZZTo2Q2Nu.root (2->0, 0.00%)
#
#
# Loading file: tree_ZZ_ZZTo4L.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topcr_Jan02/tree_ZZ_ZZTo4L.root (823716->6436, 0.78%)
#
#
# Summary:
#
# Empty input: []
#
# Empty output: ['HTbinnedWJets_2500toInf.root', 'QCD_EMEnriched_120to170.root', 'QCD_EMEnriched_170to300.root', 'QCD_EMEnriched_300toInf.root', 'QCD_EMEnriched_30to50.root', 'QCD_EMEnriched_80to120.root', 'QCD_MuEnriched_20to30.root', 'QCD_MuEnriched_30to50.root', 'QCD_MuEnriched_50to80.root', 'QCD_MuEnriched_600to800.root', 'QCD_MuEnriched_800to1000.root', 'QCD_MuEnriched_80to120.root', 'WW_WWTo4Q.root', 'ZZ_ZZTo2Q2Nu.root']
#
# CPU times: user 1min 5s, sys: 7.55 s, total: 1min 13s
# Wall time: 1min 30s

# %% [markdown]
# ### Convert them into histograms

# %%
# %%time

run_here = False

channels = ['mm', 'me', 'em', 'ee']
for channel_ in channels:
    jobname_ = outjob
    campaign_ = campaign
    dump_ = outjob.replace('tree', 'hist')+'_'+channel_
    arguments = f'extractHistsFromTrees.C("{jobname_}", "{dump_}", "{campaign_}", "{channel_}")'
    command = f"root -q -b -l '{arguments}'"
    print(f'\033[93m\nRunnning .. \n{command}\033[0m\n')

    if run_here: os.system(command)
    else: print('Run it yourself:')
    
print('Done!')
# Out:
# Runnning ..
# root -q -b -l 'extractHistsFromTrees.C("tree_2016preVFPUL_topcr_Jan02", "hist_2016preVFPUL_topcr_Jan02_mm", "2016preVFP_UL", "mm")'
#
# Run it yourself:
#
# Runnning ..
# root -q -b -l 'extractHistsFromTrees.C("tree_2016preVFPUL_topcr_Jan02", "hist_2016preVFPUL_topcr_Jan02_me", "2016preVFP_UL", "me")'
#
# Run it yourself:
#
# Runnning ..
# root -q -b -l 'extractHistsFromTrees.C("tree_2016preVFPUL_topcr_Jan02", "hist_2016preVFPUL_topcr_Jan02_em", "2016preVFP_UL", "em")'
#
# Run it yourself:
#
# Runnning ..
# root -q -b -l 'extractHistsFromTrees.C("tree_2016preVFPUL_topcr_Jan02", "hist_2016preVFPUL_topcr_Jan02_ee", "2016preVFP_UL", "ee")'
#
# Run it yourself:
# Done!
# CPU times: user 145 μs, sys: 17 μs, total: 162 μs
# Wall time: 157 μs
