# %% [markdown]
# # Python based analysis
#
# This script takes trees as inputs and writes another sets of trees as outputs.<br>
# The trees are filtered in between.

# %%
import os, sys
import numpy as np
import uproot
import pandas as pd

# %%
#Global parameters

basedir = '../input_files/trees_modified'
injob  = 'tree_2016preVFPUL_baseline_Jan02'
outjob = 'tree_2016preVFPUL_topvr_Jan03'
campaign = '2016preVFP_UL'

indir = os.path.join(basedir, injob)
outdir = os.path.join(basedir, outjob)
os.makedirs(outdir, exist_ok=True)

# %%
def read_file_into_df(filepath):

    tfile = uproot.open(filepath)
    ttree = tfile['myEvents']
    branches = ttree.keys()
    awkarray = ttree.arrays(branches)
    df = pd.DataFrame(awkarray.to_list())

    #Not filtering by channels right now.
    #if 'channel' in df.columns: df = df[df['channel'] == channelno]       
    #print(f'dataframe for {sample} {subsample} loaded.')
    return df

def write_df_into_file(df, filepath):
    if df.empty:
        data_dict = {col: np.array([], dtype=df[col].dtype) for col in df.columns}
        print(f"\033[0;31mWarning: Writing empty file: {filepath}\033[0m\n")
    else:
        data_dict = df.to_dict('list')
        
    with uproot.recreate(filepath) as file: file['myEvents'] = data_dict
    
print('Functions loaded.')
# Out:
# Functions loaded.

# %%
# %%time

list_of_files = os.listdir(indir)
list_empty_input = []
list_empty_output = []

for f in list_of_files:

    if not f.endswith('.root'): continue
    #if 'SingleMuon' not in f: continue

    #Step1: Prepare the dataframe
    print(f'\nLoading file: {f}')
    filepath = os.path.join(indir, f)
    sample = f.split("_")[1]
    subsample = "_".join(f.split("_")[2:])
       
    outfile = os.path.join(outdir, f)
    #if os.path.exists(outfile): continue
    #if 'WJets' not in f: continue

    df = read_file_into_df(filepath)
    if df.empty : 
        print(f"\033[0;31mWarning: Empty input file: {filepath}\033[0m\n")
        list_empty_input.append(filepath)

    #Creating working points on the dataframe using the NN.
    df['flag_qcd'] = (
        ((df['channel'].isin([0, 1])) & (df['nnscore_qcd_vlldmu_200_800']  < 0.30)) |
        ((df['channel'].isin([2, 3])) & (df['nnscore_qcd_vlldele_200_800'] < 0.30))
    )

    df['flag_topregion'] = (
        ((df['channel'].isin([0, 1])) & (df['nnscore_qcd_vlldmu_200_800']  > 0.50) & (df['nnscore_qcd_vlldmu_200_800']  < 0.70)) |
        ((df['channel'].isin([2, 3])) & (df['nnscore_qcd_vlldmu_200_800']  > 0.50) & (df['nnscore_qcd_vlldele_200_800'] < 0.70))
    )
    
    df['flag_searchregion'] = (
        ((df['channel'].isin([0, 1])) & (df['nnscore_qcd_vlldmu_200_800']  > 0.70)) |
        ((df['channel'].isin([2, 3])) & (df['nnscore_qcd_vlldele_200_800'] > 0.70))
    )

    # Put any cuts here on dataframe as you like
    # Define conditions as strings
    dy_veto = 'not (channel == 3 and 76 < dilep_mass < 106)'

    #Step1: Controlling QCD:
    qcd_cr = f'{dy_veto} and flag_qcd and 0.02<lep0_iso<0.15 and lep0_sip3d>5'
    qcd_vr = f'{dy_veto} and flag_qcd and 0.02<lep0_iso<0.15 and lep0_sip3d<5'

    #Step2: Controlling Drell-Yan:
    dycr  = f'76<dilep_mass<106  and dilep_ptratio > 0.7'

    tight_sip3d =  'lep0_sip3d<5 and lep1_sip3d<10'
    qcd_veto = f'{tight_sip3d} and {dy_veto} and not flag_qcd and HT>50'

    #Step3: Controlling TTbar:
    top_cr = f'{qcd_veto} and flag_topregion'
    top_vr = f'{qcd_veto} and flag_searchregion and nbjet>0'

    #Step5: Signal regions:
    sig_region = f'{qcd_veto} and flag_searchregion and nbjet == 0'
    
    #------------------------------
    # Final event selection:
    event_selection = top_vr
    #------------------------------

    # Use df.query with the combined condition
    df_filtered = df.query(event_selection)
    
    if df_filtered.empty: list_empty_output.append(f'{sample}_{subsample}')

    nbefore = len(df)
    nafter = len(df_filtered)

    frac = 0
    if nbefore != 0: frac = nafter*100/nbefore

    #display(df_filtered)

    write_df_into_file(df_filtered, outfile)
    print(f'\033[1;32mFile written: {outfile}\033[0m ({nbefore}->{nafter}, {frac:.2f}%)\n')
    #break #file

print(f'\n\033[1;33mSummary:\033[0m')
print(f'\n\033[33mEmpty input: {list_empty_input}\033[0m')
print(f'\n\033[31mEmpty output: {list_empty_output}\033[0m\n')
# Out:
# Loading file: tree_DYJetsToLL_M10to50.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_DYJetsToLL_M10to50.root (550->4, 0.73%)
#
#
# Loading file: tree_DYJetsToLL_M50.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_DYJetsToLL_M50.root (116397->50, 0.04%)
#
#
# Loading file: tree_EGamma_EGamma_B.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_EGamma_EGamma_B.root (42696->247, 0.58%)
#
#
# Loading file: tree_EGamma_EGamma_C.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_EGamma_EGamma_C.root (18737->92, 0.49%)
#
#
# Loading file: tree_EGamma_EGamma_D.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_EGamma_EGamma_D.root (30309->183, 0.60%)
#
#
# Loading file: tree_EGamma_EGamma_E.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_EGamma_EGamma_E.root (27737->157, 0.57%)
#
#
# Loading file: tree_EGamma_EGamma_F.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_EGamma_EGamma_F.root (18036->117, 0.65%)
#
#
# Loading file: tree_Higgs_bbH_HToZZTo4L.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_Higgs_bbH_HToZZTo4L.root (7697->58, 0.75%)
#
#
# Loading file: tree_Higgs_GluGluHToZZTo4L.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_Higgs_GluGluHToZZTo4L.root (18637->11, 0.06%)
#
#
# Loading file: tree_Higgs_GluGluToZH_HToZZTo4L.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_Higgs_GluGluToZH_HToZZTo4L.root (26857->362, 1.35%)
#
#
# Loading file: tree_Higgs_GluGluZH_HToWW_ZTo2L.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_Higgs_GluGluZH_HToWW_ZTo2L.root (6090->82, 1.35%)
#
#
# Loading file: tree_Higgs_ttHToNonbb.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_Higgs_ttHToNonbb.root (19554->4378, 22.39%)
#
#
# Loading file: tree_Higgs_VBF_HToZZTo4L.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_Higgs_VBF_HToZZTo4L.root (3936->11, 0.28%)
#
#
# Loading file: tree_Higgs_VHToNonbb.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_Higgs_VHToNonbb.root (2743->15, 0.55%)
#
#
# Loading file: tree_HTbinnedWJets_100to200.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_HTbinnedWJets_100to200.root (2516->15, 0.60%)
#
#
# Loading file: tree_HTbinnedWJets_1200to2500.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_HTbinnedWJets_1200to2500.root (226->4, 1.77%)
#
#
# Loading file: tree_HTbinnedWJets_200to400.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_HTbinnedWJets_200to400.root (3013->42, 1.39%)
#
#
# Loading file: tree_HTbinnedWJets_2500toInf.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_HTbinnedWJets_2500toInf.root (157->1, 0.64%)
#
#
# Loading file: tree_HTbinnedWJets_400to600.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_HTbinnedWJets_400to600.root (423->17, 4.02%)
#
#
# Loading file: tree_HTbinnedWJets_600to800.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_HTbinnedWJets_600to800.root (617->19, 3.08%)
#
#
# Loading file: tree_HTbinnedWJets_70to100.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_HTbinnedWJets_70to100.root (1473->1, 0.07%)
#
#
# Loading file: tree_HTbinnedWJets_800to1200.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_HTbinnedWJets_800to1200.root (705->14, 1.99%)
#
#
# Loading file: tree_QCD_EMEnriched_120to170.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_EMEnriched_120to170.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_EMEnriched_120to170.root (1->0, 0.00%)
#
#
# Loading file: tree_QCD_EMEnriched_170to300.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_EMEnriched_170to300.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_EMEnriched_170to300.root (6->0, 0.00%)
#
#
# Loading file: tree_QCD_EMEnriched_300toInf.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_EMEnriched_300toInf.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_EMEnriched_300toInf.root (1->0, 0.00%)
#
#
# Loading file: tree_QCD_EMEnriched_30to50.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_EMEnriched_30to50.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_EMEnriched_30to50.root (1->0, 0.00%)
#
#
# Loading file: tree_QCD_EMEnriched_80to120.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_EMEnriched_80to120.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_EMEnriched_80to120.root (2->0, 0.00%)
#
#
# Loading file: tree_QCD_MuEnriched_120to170.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_MuEnriched_120to170.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_MuEnriched_120to170.root (109->0, 0.00%)
#
#
# Loading file: tree_QCD_MuEnriched_170to300.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_MuEnriched_170to300.root (177->1, 0.56%)
#
#
# Loading file: tree_QCD_MuEnriched_20to30.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_MuEnriched_20to30.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_MuEnriched_20to30.root (3->0, 0.00%)
#
#
# Loading file: tree_QCD_MuEnriched_300to470.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_MuEnriched_300to470.root (131->1, 0.76%)
#
#
# Loading file: tree_QCD_MuEnriched_30to50.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_MuEnriched_30to50.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_MuEnriched_30to50.root (25->0, 0.00%)
#
#
# Loading file: tree_QCD_MuEnriched_470to600.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_MuEnriched_470to600.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_MuEnriched_470to600.root (79->0, 0.00%)
#
#
# Loading file: tree_QCD_MuEnriched_50to80.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_MuEnriched_50to80.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_MuEnriched_50to80.root (81->0, 0.00%)
#
#
# Loading file: tree_QCD_MuEnriched_600to800.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_MuEnriched_600to800.root (58->1, 1.72%)
#
#
# Loading file: tree_QCD_MuEnriched_800to1000.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_MuEnriched_800to1000.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_MuEnriched_800to1000.root (141->0, 0.00%)
#
#
# Loading file: tree_QCD_MuEnriched_80to120.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_MuEnriched_80to120.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_QCD_MuEnriched_80to120.root (123->0, 0.00%)
#
#
# Loading file: tree_Rare_THQ.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_Rare_THQ.root (6476->1067, 16.48%)
#
#
# Loading file: tree_Rare_THW.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_Rare_THW.root (3972->879, 22.13%)
#
#
# Loading file: tree_Rare_TTHH.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_Rare_TTHH.root (918->200, 21.79%)
#
#
# Loading file: tree_Rare_TTTJ.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_Rare_TTTJ.root (1343->423, 31.50%)
#
#
# Loading file: tree_Rare_TTTT.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_Rare_TTTT.root (26125->7728, 29.58%)
#
#
# Loading file: tree_Rare_TTTW.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_Rare_TTTW.root (2087->709, 33.97%)
#
#
# Loading file: tree_Rare_TTWH.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_Rare_TTWH.root (1760->567, 32.22%)
#
#
# Loading file: tree_Rare_TTWW.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_Rare_TTWW.root (5017->1607, 32.03%)
#
#
# Loading file: tree_Rare_TTWZ.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_Rare_TTWZ.root (1857->650, 35.00%)
#
#
# Loading file: tree_Rare_TTZH.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_Rare_TTZH.root (832->213, 25.60%)
#
#
# Loading file: tree_Rare_TTZZ.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_Rare_TTZZ.root (672->200, 29.76%)
#
#
# Loading file: tree_Rare_tZq_ll.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_Rare_tZq_ll.root (61435->9166, 14.92%)
#
#
# Loading file: tree_SingleMuon_SingleMuon_B.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_SingleMuon_SingleMuon_B.root (11057->231, 2.09%)
#
#
# Loading file: tree_SingleMuon_SingleMuon_C.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_SingleMuon_SingleMuon_C.root (4819->98, 2.03%)
#
#
# Loading file: tree_SingleMuon_SingleMuon_D.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_SingleMuon_SingleMuon_D.root (7924->163, 2.06%)
#
#
# Loading file: tree_SingleMuon_SingleMuon_E.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_SingleMuon_SingleMuon_E.root (7573->159, 2.10%)
#
#
# Loading file: tree_SingleMuon_SingleMuon_F.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_SingleMuon_SingleMuon_F.root (5122->137, 2.67%)
#
#
# Loading file: tree_SingleTop_s-channel_LeptonDecays.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_SingleTop_s-channel_LeptonDecays.root (6983->266, 3.81%)
#
#
# Loading file: tree_SingleTop_t-channel_AntiTop_InclusiveDecays.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_SingleTop_t-channel_AntiTop_InclusiveDecays.root (7797->202, 2.59%)
#
#
# Loading file: tree_SingleTop_t-channel_Top_InclusiveDecays.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_SingleTop_t-channel_Top_InclusiveDecays.root (17968->539, 3.00%)
#
#
# Loading file: tree_SingleTop_tW_AntiTop_InclusiveDecays.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_SingleTop_tW_AntiTop_InclusiveDecays.root (1904->148, 7.77%)
#
#
# Loading file: tree_SingleTop_tW_Top_InclusiveDecays.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_SingleTop_tW_Top_InclusiveDecays.root (2071->166, 8.02%)
#
#
# Loading file: tree_TTBar_TTTo2L2Nu.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_TTBar_TTTo2L2Nu.root (121998->23903, 19.59%)
#
#
# Loading file: tree_TTBar_TTToSemiLeptonic.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_TTBar_TTToSemiLeptonic.root (192565->10777, 5.60%)
#
#
# Loading file: tree_TTW_TTWToLNu.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_TTW_TTWToLNu.root (176886->53745, 30.38%)
#
#
# Loading file: tree_TTZ_TTZToLL.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_TTZ_TTZToLL.root (738166->203070, 27.51%)
#
#
# Loading file: tree_VLLD_ele_M100.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLD_ele_M100.root (3015->17, 0.56%)
#
#
# Loading file: tree_VLLD_ele_M1000.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLD_ele_M1000.root (1128->244, 21.63%)
#
#
# Loading file: tree_VLLD_ele_M200.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLD_ele_M200.root (3218->192, 5.97%)
#
#
# Loading file: tree_VLLD_ele_M300.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLD_ele_M300.root (1065->103, 9.67%)
#
#
# Loading file: tree_VLLD_ele_M400.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLD_ele_M400.root (1089->154, 14.14%)
#
#
# Loading file: tree_VLLD_ele_M600.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLD_ele_M600.root (1117->154, 13.79%)
#
#
# Loading file: tree_VLLD_ele_M800.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLD_ele_M800.root (1088->193, 17.74%)
#
#
# Loading file: tree_VLLD_mu_M100.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLD_mu_M100.root (3185->22, 0.69%)
#
#
# Loading file: tree_VLLD_mu_M200.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLD_mu_M200.root (1870->102, 5.45%)
#
#
# Loading file: tree_VLLD_mu_M300.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLD_mu_M300.root (562->54, 9.61%)
#
#
# Loading file: tree_VLLD_mu_M400.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLD_mu_M400.root (518->64, 12.36%)
#
#
# Loading file: tree_VLLD_mu_M600.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLD_mu_M600.root (473->72, 15.22%)
#
#
# Loading file: tree_VLLD_mu_M800.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLD_mu_M800.root (454->64, 14.10%)
#
#
# Loading file: tree_VLLS_ele_M100.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_ele_M100.root (835->6, 0.72%)
#
#
# Loading file: tree_VLLS_ele_M1000.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_ele_M1000.root (1218->256, 21.02%)
#
#
# Loading file: tree_VLLS_ele_M125.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_ele_M125.root (3362->70, 2.08%)
#
#
# Loading file: tree_VLLS_ele_M150.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_ele_M150.root (4713->144, 3.06%)
#
#
# Loading file: tree_VLLS_ele_M200.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_ele_M200.root (5965->368, 6.17%)
#
#
# Loading file: tree_VLLS_ele_M250.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_ele_M250.root (5238->495, 9.45%)
#
#
# Loading file: tree_VLLS_ele_M300.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_ele_M300.root (5538->539, 9.73%)
#
#
# Loading file: tree_VLLS_ele_M350.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_ele_M350.root (2259->249, 11.02%)
#
#
# Loading file: tree_VLLS_ele_M400.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_ele_M400.root (2402->326, 13.57%)
#
#
# Loading file: tree_VLLS_ele_M450.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_ele_M450.root (2343->349, 14.90%)
#
#
# Loading file: tree_VLLS_ele_M500.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_ele_M500.root (2356->357, 15.15%)
#
#
# Loading file: tree_VLLS_ele_M750.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_ele_M750.root (1212->235, 19.39%)
#
#
# Loading file: tree_VLLS_mu_M100.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_mu_M100.root (879->7, 0.80%)
#
#
# Loading file: tree_VLLS_mu_M1000.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_mu_M1000.root (718->105, 14.62%)
#
#
# Loading file: tree_VLLS_mu_M125.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_mu_M125.root (3755->64, 1.70%)
#
#
# Loading file: tree_VLLS_mu_M150.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_mu_M150.root (4398->101, 2.30%)
#
#
# Loading file: tree_VLLS_mu_M200.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_mu_M200.root (5087->209, 4.11%)
#
#
# Loading file: tree_VLLS_mu_M250.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_mu_M250.root (4320->272, 6.30%)
#
#
# Loading file: tree_VLLS_mu_M300.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_mu_M300.root (4460->316, 7.09%)
#
#
# Loading file: tree_VLLS_mu_M400.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_mu_M400.root (1722->191, 11.09%)
#
#
# Loading file: tree_VLLS_mu_M450.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_mu_M450.root (1648->162, 9.83%)
#
#
# Loading file: tree_VLLS_mu_M500.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_mu_M500.root (1668->202, 12.11%)
#
#
# Loading file: tree_VLLS_mu_M750.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_mu_M750.root (841->99, 11.77%)
#
#
# Loading file: tree_VLLS_tau_M100.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_tau_M100.root (1137->12, 1.06%)
#
#
# Loading file: tree_VLLS_tau_M125.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_tau_M125.root (2890->27, 0.93%)
#
#
# Loading file: tree_VLLS_tau_M150.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_tau_M150.root (3883->77, 1.98%)
#
#
# Loading file: tree_VLLS_tau_M200.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_tau_M200.root (5001->184, 3.68%)
#
#
# Loading file: tree_VLLS_tau_M250.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_tau_M250.root (4539->263, 5.79%)
#
#
# Loading file: tree_VLLS_tau_M300.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_tau_M300.root (4972->350, 7.04%)
#
#
# Loading file: tree_VLLS_tau_M350.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_tau_M350.root (2022->169, 8.36%)
#
#
# Loading file: tree_VLLS_tau_M400.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_VLLS_tau_M400.root (2144->217, 10.12%)
#
#
# Loading file: tree_WGamma_WGToLNuG_01J.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_WGamma_WGToLNuG_01J.root (90029->334, 0.37%)
#
#
# Loading file: tree_WpWp_WpWpJJEWK.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_WpWp_WpWpJJEWK.root (16890->279, 1.65%)
#
#
# Loading file: tree_WWW_Inclusive.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_WWW_Inclusive.root (952->11, 1.16%)
#
#
# Loading file: tree_WWZ_Inclusive.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_WWZ_Inclusive.root (286->5, 1.75%)
#
#
# Loading file: tree_WW_WWTo1L1Nu2Q.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_WW_WWTo1L1Nu2Q.root (3036->24, 0.79%)
#
#
# Loading file: tree_WW_WWTo2L2Nu.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_WW_WWTo2L2Nu.root (5288->21, 0.40%)
#
#
# Loading file: tree_WW_WWTo4Q.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_WW_WWTo4Q.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_WW_WWTo4Q.root (8->0, 0.00%)
#
#
# Loading file: tree_WZZ_Inclusive.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_WZZ_Inclusive.root (658->21, 3.19%)
#
#
# Loading file: tree_WZ_WZTo1L1Nu2Q.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_WZ_WZTo1L1Nu2Q.root (753->2, 0.27%)
#
#
# Loading file: tree_WZ_WZTo2L2Q.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_WZ_WZTo2L2Q.root (21719->44, 0.20%)
#
#
# Loading file: tree_WZ_WZTo3LNu.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_WZ_WZTo3LNu.root (344190->1944, 0.56%)
#
#
# Loading file: tree_ZGamma_ZGToLLG_01J.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_ZGamma_ZGToLLG_01J.root (63453->96, 0.15%)
#
#
# Loading file: tree_ZZZ_Inclusive.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_ZZZ_Inclusive.root (119->4, 3.36%)
#
#
# Loading file: tree_ZZ_ZZTo2L2Nu.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_ZZ_ZZTo2L2Nu.root (22945->26, 0.11%)
#
#
# Loading file: tree_ZZ_ZZTo2Q2L.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_ZZ_ZZTo2Q2L.root (26501->174, 0.66%)
#
#
# Loading file: tree_ZZ_ZZTo2Q2Nu.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_ZZ_ZZTo2Q2Nu.root
#
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_ZZ_ZZTo2Q2Nu.root (2->0, 0.00%)
#
#
# Loading file: tree_ZZ_ZZTo4L.root
# File written: ../input_files/trees_modified/tree_2016preVFPUL_topvr_Jan03/tree_ZZ_ZZTo4L.root (823716->1692, 0.21%)
#
#
# Summary:
#
# Empty input: []
#
# Empty output: ['QCD_EMEnriched_120to170.root', 'QCD_EMEnriched_170to300.root', 'QCD_EMEnriched_300toInf.root', 'QCD_EMEnriched_30to50.root', 'QCD_EMEnriched_80to120.root', 'QCD_MuEnriched_120to170.root', 'QCD_MuEnriched_20to30.root', 'QCD_MuEnriched_30to50.root', 'QCD_MuEnriched_470to600.root', 'QCD_MuEnriched_50to80.root', 'QCD_MuEnriched_800to1000.root', 'QCD_MuEnriched_80to120.root', 'WW_WWTo4Q.root', 'ZZ_ZZTo2Q2Nu.root']
#
# CPU times: user 1min 12s, sys: 7.9 s, total: 1min 20s
# Wall time: 1min 47s

# %% [markdown]
# ### Convert them into histograms

# %%
# %%time

run_here = False

channels = ['mm', 'me', 'em', 'ee']
for channel_ in channels:
    jobname_ = outjob
    campaign_ = campaign
    dump_ = outjob.replace('tree', 'hist')+'_'+channel_
    arguments = f'extractHistsFromTrees.C("{jobname_}", "{dump_}", "{campaign_}", "{channel_}")'
    command = f"root -q -b -l '{arguments}'"
    print(f'\033[93m\nRunnning .. \n{command}\033[0m\n')

    if run_here: os.system(command)
    else: print('Run it yourself:')
    
print('Done!')
# Out:
# Runnning ..
# root -q -b -l 'extractHistsFromTrees.C("tree_2016preVFPUL_topvr_Jan03", "hist_2016preVFPUL_topvr_Jan03_mm", "2016preVFP_UL", "mm")'
#
# Run it yourself:
#
# Runnning ..
# root -q -b -l 'extractHistsFromTrees.C("tree_2016preVFPUL_topvr_Jan03", "hist_2016preVFPUL_topvr_Jan03_me", "2016preVFP_UL", "me")'
#
# Run it yourself:
#
# Runnning ..
# root -q -b -l 'extractHistsFromTrees.C("tree_2016preVFPUL_topvr_Jan03", "hist_2016preVFPUL_topvr_Jan03_em", "2016preVFP_UL", "em")'
#
# Run it yourself:
#
# Runnning ..
# root -q -b -l 'extractHistsFromTrees.C("tree_2016preVFPUL_topvr_Jan03", "hist_2016preVFPUL_topvr_Jan03_ee", "2016preVFP_UL", "ee")'
#
# Run it yourself:
# Done!
# CPU times: user 232 μs, sys: 26 μs, total: 258 μs
# Wall time: 252 μs
