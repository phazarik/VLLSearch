# %% [markdown]
# # Python based analysis
#
# This script takes trees as inputs and writes another sets of trees as outputs.<br>
# The trees are filtered in between.

# %%
import os, sys
import numpy as np
import uproot
import pandas as pd

# %%
#Global parameters

basedir = '../input_files/trees_modified'
injob  = 'baseline/tree_2016postVFPUL_baseline'
outjob = 'tree_2016postVFPUL_qcdvr'
campaign = '2016postVFP_UL'

indir = os.path.join(basedir, injob)
outdir = os.path.join(basedir, outjob)
os.makedirs(outdir, exist_ok=True)

# %%
def read_file_into_df(filepath):

    tfile = uproot.open(filepath)
    ttree = tfile['myEvents']
    branches = ttree.keys()
    awkarray = ttree.arrays(branches)
    df = pd.DataFrame(awkarray.to_list())

    #Not filtering by channels right now.
    #if 'channel' in df.columns: df = df[df['channel'] == channelno]       
    #print(f'dataframe for {sample} {subsample} loaded.')
    return df

def write_df_into_file(df, filepath):
    if df.empty:
        data_dict = {col: np.array([], dtype=df[col].dtype) for col in df.columns}
        print(f"\033[0;31mWarning: Writing empty file: {filepath}\033[0m\n")
    else:
        data_dict = df.to_dict('list')
        
    with uproot.recreate(filepath) as file: file['myEvents'] = data_dict
    
print('Functions loaded.')
# Out:
# Functions loaded.

# %%
# %%time

list_of_files = os.listdir(indir)
list_empty_input = []
list_empty_output = []

for f in list_of_files:

    if not f.endswith('.root'): continue
    #if 'SingleMuon' not in f: continue

    #Step1: Prepare the dataframe
    print(f'\nLoading file: {f}')
    filepath = os.path.join(indir, f)
    sample = f.split("_")[1]
    subsample = "_".join(f.split("_")[2:])
       
    outfile = os.path.join(outdir, f)
    #if os.path.exists(outfile): continue
    #if 'WJets' not in f: continue

    df = read_file_into_df(filepath)
    if df.empty : 
        print(f"\033[0;31mWarning: Empty input file: {filepath}\033[0m\n")
        list_empty_input.append(filepath)

    #Creating working points on the dataframe using the NN.
    df['flag_qcd'] = (
        ((df['channel'].isin([0, 1])) & (df['nnscore_qcd_vlldmu_200_800']  < 0.30)) |
        ((df['channel'].isin([2, 3])) & (df['nnscore_qcd_vlldele_200_800'] < 0.30))
    )

    df['flag_topregion'] = (
        ((df['channel'].isin([0, 1])) & (df['nnscore_qcd_vlldmu_200_800']  > 0.50) & (df['nnscore_qcd_vlldmu_200_800']  < 0.70)) |
        ((df['channel'].isin([2, 3])) & (df['nnscore_qcd_vlldmu_200_800']  > 0.50) & (df['nnscore_qcd_vlldele_200_800'] < 0.70))
    )
    
    df['flag_searchregion'] = (
        ((df['channel'].isin([0, 1])) & (df['nnscore_qcd_vlldmu_200_800']  > 0.70)) |
        ((df['channel'].isin([2, 3])) & (df['nnscore_qcd_vlldele_200_800'] > 0.70))
    )

    # Put any cuts here on dataframe as you like
    # Define conditions as strings
    dy_veto = 'not (channel == 3 and 76 < dilep_mass < 106)'

    #Step1: Controlling QCD:
    qcd_cr = f'{dy_veto} and flag_qcd and 0.02<lep0_iso<0.15 and lep0_sip3d>5'
    qcd_vr = f'{dy_veto} and flag_qcd and 0.02<lep0_iso<0.15 and lep0_sip3d<5'

    #Step2: Controlling Drell-Yan:
    dycr  = f'76<dilep_mass<106  and dilep_ptratio > 0.7'

    tight_sip3d =  'lep0_sip3d<5 and lep1_sip3d<10'
    qcd_veto = f'{tight_sip3d} and {dy_veto} and not flag_qcd and HT>50'

    #Step3: Controlling TTbar:
    top_cr = f'{qcd_veto} and flag_topregion'
    top_vr = f'{qcd_veto} and flag_searchregion and nbjet>0'

    #Step5: Signal regions:
    sig_region = f'{qcd_veto} and flag_searchregion and nbjet == 0'
    
    #------------------------------
    # Final event selection:
    event_selection = qcd_vr
    #------------------------------

    # Use df.query with the combined condition
    df_filtered = df.query(event_selection)
    
    if df_filtered.empty: list_empty_output.append(f'{sample}_{subsample}')

    nbefore = len(df)
    nafter = len(df_filtered)

    frac = 0
    if nbefore != 0: frac = nafter*100/nbefore

    #display(df_filtered)

    write_df_into_file(df_filtered, outfile)
    print(f'\033[1;32mFile written: {outfile}\033[0m ({nbefore} -> {nafter}, {frac:.2f}%)\n')
    #break #file

print(f'\n\033[1;33mSummary:\033[0m')
print(f'\n\033[33mEmpty input: {list_empty_input}\033[0m')
print(f'\n\033[31mEmpty output: {list_empty_output}\033[0m\n')
# Out:
# Loading file: tree_DYJetsToLL_M10to50.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_DYJetsToLL_M10to50.root (127->27, 21.26%)
#
#
# Loading file: tree_DYJetsToLL_M50.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_DYJetsToLL_M50.root (90748->2335, 2.57%)
#
#
# Loading file: tree_EGamma_EGamma_F.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_EGamma_EGamma_F.root (2827->114, 4.03%)
#
#
# Loading file: tree_EGamma_EGamma_G.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_EGamma_EGamma_G.root (50711->1872, 3.69%)
#
#
# Loading file: tree_EGamma_EGamma_H.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_EGamma_EGamma_H.root (56797->2062, 3.63%)
#
#
# Loading file: tree_Higgs_bbH_HToZZTo4L.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_Higgs_bbH_HToZZTo4L.root (7150->1461, 20.43%)
#
#
# Loading file: tree_Higgs_GluGluHToZZTo4L.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_Higgs_GluGluHToZZTo4L.root (18012->3439, 19.09%)
#
#
# Loading file: tree_Higgs_GluGluToZH_HToZZTo4L.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_Higgs_GluGluToZH_HToZZTo4L.root (25725->2622, 10.19%)
#
#
# Loading file: tree_Higgs_GluGluZH_HToWW_ZTo2L.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_Higgs_GluGluZH_HToWW_ZTo2L.root (5695->460, 8.08%)
#
#
# Loading file: tree_Higgs_ttHToNonbb.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_Higgs_ttHToNonbb.root (9002->1061, 11.79%)
#
#
# Loading file: tree_Higgs_VBF_HToZZTo4L.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_Higgs_VBF_HToZZTo4L.root (10289->1712, 16.64%)
#
#
# Loading file: tree_Higgs_VHToNonbb.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_Higgs_VHToNonbb.root (2148->214, 9.96%)
#
#
# Loading file: tree_HTbinnedWJets_100to200.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_HTbinnedWJets_100to200.root (2336->330, 14.13%)
#
#
# Loading file: tree_HTbinnedWJets_1200to2500.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_HTbinnedWJets_1200to2500.root (678->166, 24.48%)
#
#
# Loading file: tree_HTbinnedWJets_200to400.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_HTbinnedWJets_200to400.root (2626->377, 14.36%)
#
#
# Loading file: tree_HTbinnedWJets_2500toInf.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_HTbinnedWJets_2500toInf.root (240->58, 24.17%)
#
#
# Loading file: tree_HTbinnedWJets_400to600.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_HTbinnedWJets_400to600.root (482->76, 15.77%)
#
#
# Loading file: tree_HTbinnedWJets_600to800.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_HTbinnedWJets_600to800.root (539->73, 13.54%)
#
#
# Loading file: tree_HTbinnedWJets_70to100.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_HTbinnedWJets_70to100.root (912->124, 13.60%)
#
#
# Loading file: tree_HTbinnedWJets_800to1200.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_HTbinnedWJets_800to1200.root (550->91, 16.55%)
#
#
# Loading file: tree_QCD_EMEnriched_120to170.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_QCD_EMEnriched_120to170.root (5->2, 40.00%)
#
#
# Loading file: tree_QCD_EMEnriched_170to300.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_QCD_EMEnriched_170to300.root
#
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_QCD_EMEnriched_170to300.root (2->0, 0.00%)
#
#
# Loading file: tree_QCD_EMEnriched_20to30.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_QCD_EMEnriched_20to30.root (1->1, 100.00%)
#
#
# Loading file: tree_QCD_EMEnriched_300toInf.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_QCD_EMEnriched_300toInf.root
#
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_QCD_EMEnriched_300toInf.root (1->0, 0.00%)
#
#
# Loading file: tree_QCD_EMEnriched_50to80.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_QCD_EMEnriched_50to80.root (3->2, 66.67%)
#
#
# Loading file: tree_QCD_EMEnriched_80to120.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_QCD_EMEnriched_80to120.root (3->1, 33.33%)
#
#
# Loading file: tree_QCD_MuEnriched_120to170.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_QCD_MuEnriched_120to170.root (116->38, 32.76%)
#
#
# Loading file: tree_QCD_MuEnriched_170to300.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_QCD_MuEnriched_170to300.root (159->48, 30.19%)
#
#
# Loading file: tree_QCD_MuEnriched_20to30.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_QCD_MuEnriched_20to30.root
#
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_QCD_MuEnriched_20to30.root (1->0, 0.00%)
#
#
# Loading file: tree_QCD_MuEnriched_300to470.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_QCD_MuEnriched_300to470.root (116->28, 24.14%)
#
#
# Loading file: tree_QCD_MuEnriched_30to50.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_QCD_MuEnriched_30to50.root (43->20, 46.51%)
#
#
# Loading file: tree_QCD_MuEnriched_470to600.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_QCD_MuEnriched_470to600.root (69->17, 24.64%)
#
#
# Loading file: tree_QCD_MuEnriched_50to80.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_QCD_MuEnriched_50to80.root (92->32, 34.78%)
#
#
# Loading file: tree_QCD_MuEnriched_600to800.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_QCD_MuEnriched_600to800.root (72->23, 31.94%)
#
#
# Loading file: tree_QCD_MuEnriched_800to1000.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_QCD_MuEnriched_800to1000.root (119->44, 36.97%)
#
#
# Loading file: tree_QCD_MuEnriched_80to120.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_QCD_MuEnriched_80to120.root (117->52, 44.44%)
#
#
# Loading file: tree_Rare_THQ.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_Rare_THQ.root (6262->624, 9.96%)
#
#
# Loading file: tree_Rare_THW.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_Rare_THW.root (8908->621, 6.97%)
#
#
# Loading file: tree_Rare_TTHH.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_Rare_TTHH.root (981->124, 12.64%)
#
#
# Loading file: tree_Rare_TTTJ.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_Rare_TTTJ.root (1499->140, 9.34%)
#
#
# Loading file: tree_Rare_TTTT.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_Rare_TTTT.root (28270->3523, 12.46%)
#
#
# Loading file: tree_Rare_TTTW.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_Rare_TTTW.root (2314->192, 8.30%)
#
#
# Loading file: tree_Rare_TTWH.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_Rare_TTWH.root (2186->175, 8.01%)
#
#
# Loading file: tree_Rare_TTWW.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_Rare_TTWW.root (5761->406, 7.05%)
#
#
# Loading file: tree_Rare_TTWZ.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_Rare_TTWZ.root (2046->128, 6.26%)
#
#
# Loading file: tree_Rare_TTZH.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_Rare_TTZH.root (978->100, 10.22%)
#
#
# Loading file: tree_Rare_TTZZ.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_Rare_TTZZ.root (691->40, 5.79%)
#
#
# Loading file: tree_Rare_tZq_ll.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_Rare_tZq_ll.root (66871->5435, 8.13%)
#
#
# Loading file: tree_SingleMuon_SingleMuon_F.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_SingleMuon_SingleMuon_F.root (815->215, 26.38%)
#
#
# Loading file: tree_SingleMuon_SingleMuon_G.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_SingleMuon_SingleMuon_G.root (15389->3908, 25.39%)
#
#
# Loading file: tree_SingleMuon_SingleMuon_H.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_SingleMuon_SingleMuon_H.root (18433->4636, 25.15%)
#
#
# Loading file: tree_SingleTop_s-channel_LeptonDecays.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_SingleTop_s-channel_LeptonDecays.root (6972->1085, 15.56%)
#
#
# Loading file: tree_SingleTop_t-channel_AntiTop_InclusiveDecays.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_SingleTop_t-channel_AntiTop_InclusiveDecays.root (9439->1533, 16.24%)
#
#
# Loading file: tree_SingleTop_t-channel_Top_InclusiveDecays.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_SingleTop_t-channel_Top_InclusiveDecays.root (21214->3447, 16.25%)
#
#
# Loading file: tree_SingleTop_tW_AntiTop_InclusiveDecays.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_SingleTop_tW_AntiTop_InclusiveDecays.root (2130->255, 11.97%)
#
#
# Loading file: tree_SingleTop_tW_Top_InclusiveDecays.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_SingleTop_tW_Top_InclusiveDecays.root (2154->235, 10.91%)
#
#
# Loading file: tree_TTBar_TTTo2L2Nu.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_TTBar_TTTo2L2Nu.root (137918->10389, 7.53%)
#
#
# Loading file: tree_TTBar_TTToSemiLeptonic.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_TTBar_TTToSemiLeptonic.root (216649->33831, 15.62%)
#
#
# Loading file: tree_TTW_TTWToLNu.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_TTW_TTWToLNu.root (211024->15158, 7.18%)
#
#
# Loading file: tree_TTZ_TTZToLL.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_TTZ_TTZToLL.root (611412->42371, 6.93%)
#
#
# Loading file: tree_VLLD_ele_M100.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLD_ele_M100.root (3015->349, 11.58%)
#
#
# Loading file: tree_VLLD_ele_M1000.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLD_ele_M1000.root (1128->8, 0.71%)
#
#
# Loading file: tree_VLLD_ele_M200.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLD_ele_M200.root (3218->79, 2.45%)
#
#
# Loading file: tree_VLLD_ele_M300.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLD_ele_M300.root (1065->15, 1.41%)
#
#
# Loading file: tree_VLLD_ele_M400.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLD_ele_M400.root (1089->12, 1.10%)
#
#
# Loading file: tree_VLLD_ele_M600.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLD_ele_M600.root (1117->10, 0.90%)
#
#
# Loading file: tree_VLLD_ele_M800.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLD_ele_M800.root (1088->5, 0.46%)
#
#
# Loading file: tree_VLLD_mu_M100.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLD_mu_M100.root (3185->490, 15.38%)
#
#
# Loading file: tree_VLLD_mu_M200.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLD_mu_M200.root (1870->100, 5.35%)
#
#
# Loading file: tree_VLLD_mu_M300.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLD_mu_M300.root (562->10, 1.78%)
#
#
# Loading file: tree_VLLD_mu_M400.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLD_mu_M400.root (518->1, 0.19%)
#
#
# Loading file: tree_VLLD_mu_M600.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLD_mu_M600.root (473->1, 0.21%)
#
#
# Loading file: tree_VLLD_mu_M800.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLD_mu_M800.root (454->1, 0.22%)
#
#
# Loading file: tree_VLLS_ele_M100.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_ele_M100.root (835->80, 9.58%)
#
#
# Loading file: tree_VLLS_ele_M1000.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_ele_M1000.root (1218->4, 0.33%)
#
#
# Loading file: tree_VLLS_ele_M125.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_ele_M125.root (3362->269, 8.00%)
#
#
# Loading file: tree_VLLS_ele_M150.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_ele_M150.root (4713->218, 4.63%)
#
#
# Loading file: tree_VLLS_ele_M200.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_ele_M200.root (5965->115, 1.93%)
#
#
# Loading file: tree_VLLS_ele_M250.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_ele_M250.root (5238->72, 1.37%)
#
#
# Loading file: tree_VLLS_ele_M300.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_ele_M300.root (5538->42, 0.76%)
#
#
# Loading file: tree_VLLS_ele_M350.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_ele_M350.root (2259->12, 0.53%)
#
#
# Loading file: tree_VLLS_ele_M400.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_ele_M400.root (2402->20, 0.83%)
#
#
# Loading file: tree_VLLS_ele_M450.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_ele_M450.root (2343->12, 0.51%)
#
#
# Loading file: tree_VLLS_ele_M500.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_ele_M500.root (2356->10, 0.42%)
#
#
# Loading file: tree_VLLS_ele_M750.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_ele_M750.root (1212->7, 0.58%)
#
#
# Loading file: tree_VLLS_mu_M100.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_mu_M100.root (879->89, 10.13%)
#
#
# Loading file: tree_VLLS_mu_M1000.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_mu_M1000.root (718->4, 0.56%)
#
#
# Loading file: tree_VLLS_mu_M125.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_mu_M125.root (3755->419, 11.16%)
#
#
# Loading file: tree_VLLS_mu_M150.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_mu_M150.root (4398->379, 8.62%)
#
#
# Loading file: tree_VLLS_mu_M200.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_mu_M200.root (5087->249, 4.89%)
#
#
# Loading file: tree_VLLS_mu_M250.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_mu_M250.root (4320->99, 2.29%)
#
#
# Loading file: tree_VLLS_mu_M300.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_mu_M300.root (4460->70, 1.57%)
#
#
# Loading file: tree_VLLS_mu_M400.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_mu_M400.root (1722->12, 0.70%)
#
#
# Loading file: tree_VLLS_mu_M450.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_mu_M450.root (1648->9, 0.55%)
#
#
# Loading file: tree_VLLS_mu_M500.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_mu_M500.root (1668->10, 0.60%)
#
#
# Loading file: tree_VLLS_mu_M750.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_mu_M750.root (841->3, 0.36%)
#
#
# Loading file: tree_VLLS_tau_M100.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_tau_M100.root (1137->98, 8.62%)
#
#
# Loading file: tree_VLLS_tau_M125.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_tau_M125.root (2890->278, 9.62%)
#
#
# Loading file: tree_VLLS_tau_M150.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_tau_M150.root (3883->331, 8.52%)
#
#
# Loading file: tree_VLLS_tau_M200.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_tau_M200.root (5001->288, 5.76%)
#
#
# Loading file: tree_VLLS_tau_M250.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_tau_M250.root (4539->180, 3.97%)
#
#
# Loading file: tree_VLLS_tau_M300.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_tau_M300.root (4972->158, 3.18%)
#
#
# Loading file: tree_VLLS_tau_M350.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_tau_M350.root (2022->52, 2.57%)
#
#
# Loading file: tree_VLLS_tau_M400.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_VLLS_tau_M400.root (2144->57, 2.66%)
#
#
# Loading file: tree_WGamma_WGToLNuG_01J.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_WGamma_WGToLNuG_01J.root (93400->11262, 12.06%)
#
#
# Loading file: tree_WpWp_WpWpJJEWK.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_WpWp_WpWpJJEWK.root (17544->999, 5.69%)
#
#
# Loading file: tree_WWW_Inclusive.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_WWW_Inclusive.root (994->61, 6.14%)
#
#
# Loading file: tree_WWZ_Inclusive.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_WWZ_Inclusive.root (231->15, 6.49%)
#
#
# Loading file: tree_WW_WWTo1L1Nu2Q.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_WW_WWTo1L1Nu2Q.root (3125->455, 14.56%)
#
#
# Loading file: tree_WW_WWTo2L2Nu.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_WW_WWTo2L2Nu.root (4760->319, 6.70%)
#
#
# Loading file: tree_WW_WWTo4Q.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_WW_WWTo4Q.root (3->1, 33.33%)
#
#
# Loading file: tree_WZZ_Inclusive.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_WZZ_Inclusive.root (538->34, 6.32%)
#
#
# Loading file: tree_WZ_WZTo1L1Nu2Q.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_WZ_WZTo1L1Nu2Q.root (772->131, 16.97%)
#
#
# Loading file: tree_WZ_WZTo2L2Q.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_WZ_WZTo2L2Q.root (17568->572, 3.26%)
#
#
# Loading file: tree_WZ_WZTo3LNu.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_WZ_WZTo3LNu.root (377171->37185, 9.86%)
#
#
# Loading file: tree_ZGamma_ZGToLLG_01J.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_ZGamma_ZGToLLG_01J.root (83680->12579, 15.03%)
#
#
# Loading file: tree_ZZZ_Inclusive.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_ZZZ_Inclusive.root (105->7, 6.67%)
#
#
# Loading file: tree_ZZ_ZZTo2L2Nu.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_ZZ_ZZTo2L2Nu.root (20261->187, 0.92%)
#
#
# Loading file: tree_ZZ_ZZTo2Q2L.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_ZZ_ZZTo2Q2L.root (20052->888, 4.43%)
#
#
# Loading file: tree_ZZ_ZZTo2Q2Nu.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_ZZ_ZZTo2Q2Nu.root
#
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_ZZ_ZZTo2Q2Nu.root (1->0, 0.00%)
#
#
# Loading file: tree_ZZ_ZZTo4L.root
# File written: ../input_files/trees_modified/tree_2016postVFPUL_qcdvr/tree_ZZ_ZZTo4L.root (860584->153494, 17.84%)
#
#
# Summary:
#
# Empty input: []
#
# Empty output: ['QCD_EMEnriched_170to300.root', 'QCD_EMEnriched_300toInf.root', 'QCD_MuEnriched_20to30.root', 'ZZ_ZZTo2Q2Nu.root']
#
# CPU times: user 1min 16s, sys: 8.62 s, total: 1min 25s
# Wall time: 1min 56s

# %% [markdown]
# ### Convert them into histograms

# %%
# %%time

run_here = False

channels = ['mm', 'me', 'em', 'ee']
for channel_ in channels:
    jobname_ = outjob
    campaign_ = campaign
    dump_ = outjob.replace('tree', 'hist')+'_'+channel_
    arguments = f'extractHistsFromTrees.C("{jobname_}", "{dump_}", "{campaign_}", "{channel_}")'
    command = f"root -q -b -l '{arguments}'"
    print(f'\033[93m\nRunnning .. \n{command}\033[0m\n')

    if run_here: os.system(command)
    else: print('Run it yourself:')
    
print('Done!')
# Out:
# Runnning ..
# root -q -b -l 'extractHistsFromTrees.C("tree_2016postVFPUL_qcdvr", "hist_2016postVFPUL_qcdvr_mm", "2016postVFP_UL", "mm")'
#
# Run it yourself:
#
# Runnning ..
# root -q -b -l 'extractHistsFromTrees.C("tree_2016postVFPUL_qcdvr", "hist_2016postVFPUL_qcdvr_me", "2016postVFP_UL", "me")'
#
# Run it yourself:
#
# Runnning ..
# root -q -b -l 'extractHistsFromTrees.C("tree_2016postVFPUL_qcdvr", "hist_2016postVFPUL_qcdvr_em", "2016postVFP_UL", "em")'
#
# Run it yourself:
#
# Runnning ..
# root -q -b -l 'extractHistsFromTrees.C("tree_2016postVFPUL_qcdvr", "hist_2016postVFPUL_qcdvr_ee", "2016postVFP_UL", "ee")'
#
# Run it yourself:
# Done!
# CPU times: user 233 μs, sys: 26 μs, total: 259 μs
# Wall time: 244 μs
