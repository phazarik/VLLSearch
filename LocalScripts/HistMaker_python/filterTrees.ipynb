# %% [markdown]
# # Python based analysis
#
# This script takes trees as inputs and writes another sets of trees as outputs.<br>
# The trees are filtered in between.

# %%
import os, sys
import numpy as np
import uproot
import pandas as pd

# %%
#Global parameters

basedir = '../input_files/trees_modified'
injob  = 'tree_2018UL_baseline_Dec30'
outjob = 'tree_2018UL_sr_Dec30'
#channelno = 0 #mumu
#channelno = 3 #ee
campaign = '2018_UL'

indir = os.path.join(basedir, injob)
outdir = os.path.join(basedir, outjob)
os.makedirs(outdir, exist_ok=True)

# %%
def read_file_into_df(filepath):

    tfile = uproot.open(filepath)
    ttree = tfile['myEvents']
    branches = ttree.keys()
    awkarray = ttree.arrays(branches)
    df = pd.DataFrame(awkarray.to_list())

    #Not filtering by channels right now.
    #if 'channel' in df.columns: df = df[df['channel'] == channelno]       
    #print(f'dataframe for {sample} {subsample} loaded.')
    return df

def write_df_into_file(df, filepath):
    if df.empty:
        data_dict = {col: np.array([], dtype=df[col].dtype) for col in df.columns}
        print(f"\033[0;31mWarning: Writing empty file: {filepath}\033[0m\n")
    else:
        data_dict = df.to_dict('list')
        
    with uproot.recreate(filepath) as file: file['myEvents'] = data_dict
    
print('Functions loaded.')
# Out:
# Functions loaded.

# %%
# %%time

list_of_files = os.listdir(indir)
list_empty_input = []
list_empty_output = []

for f in list_of_files:

    #if 'SingleMuon' not in f: continue

    #Step1: Prepare the dataframe
    print(f'\nLoading file: {f}')
    filepath = os.path.join(indir, f)
    sample = f.split("_")[1]
    subsample = "_".join(f.split("_")[2:])
       
    outfile = os.path.join(outdir, f)
    #if os.path.exists(outfile): continue
    #if 'WJets' not in f: continue

    df = read_file_into_df(filepath)
    if df.empty : 
        print(f"\033[0;31mWarning: Empty input file: {filepath}\033[0m\n")
        list_empty_input.append(filepath)

    #Creating working points on the dataframe using the NN.
    df['flag_qcd'] = (
        ((df['channel'].isin([0, 1])) & (df['nnscore_qcd_vlldmu_200_800']  < 0.30)) |
        ((df['channel'].isin([2, 3])) & (df['nnscore_qcd_vlldele_200_800'] < 0.30))
    )

    df['flag_topregion'] = (
        ((df['channel'].isin([0, 1])) & (df['nnscore_qcd_vlldmu_200_800']  > 0.50) & (df['nnscore_qcd_vlldmu_200_800']  < 0.70)) |
        ((df['channel'].isin([2, 3])) & (df['nnscore_qcd_vlldmu_200_800']  > 0.50) & (df['nnscore_qcd_vlldele_200_800'] < 0.70))
    )
    
    df['flag_searchregion'] = (
        ((df['channel'].isin([0, 1])) & (df['nnscore_qcd_vlldmu_200_800']  > 0.70)) |
        ((df['channel'].isin([2, 3])) & (df['nnscore_qcd_vlldele_200_800'] > 0.70))
    )

    # Put any cuts here on dataframe as you like
    # Define conditions as strings
    dy_veto = 'not (channel == 3 and 76 < dilep_mass < 106)'

    #Step1: Controlling QCD:
    qcdcr = f'{dy_veto} and flag_qcd and 0.02<lep0_iso<0.15 and lep0_sip3d>5'
    qcdvr = f'{dy_veto} and flag_qcd and 0.02<lep0_iso<0.15 and lep0_sip3d<5'

    #Step2: Controlling Drell-Yan:
    dycr  = f'76<dilep_mass<106  and dilep_ptratio > 0.7'

    tight_sip3d =  'lep0_sip3d<5 and lep1_sip3d<10'
    qcd_veto = f'{tight_sip3d} and {dy_veto} and not flag_qcd and HT>50'

    #Step3: Controlling TTbar:
    top_cr = f'{qcd_veto} and flag_topregion'
    top_vr = f'{qcd_veto} and flag_searchregion and nbjet>0'

    #Step5: Signal regions:
    sig_region = f'{qcd_veto} and flag_searchregion and nbjet == 0'
    
    #------------------------------
    # Final event selection:
    event_selection = sig_region
    #------------------------------

    # Use df.query with the combined condition
    df_filtered = df.query(event_selection)
    
    if df_filtered.empty: list_empty_output.append(f'{sample}_{subsample}')

    nbefore = len(df)
    nafter = len(df_filtered)

    frac = 0
    if nbefore != 0: frac = nafter*100/nbefore

    #display(df_filtered)

    write_df_into_file(df_filtered, outfile)
    print(f'\033[1;32mFile written: {outfile}\033[0m ({nbefore}->{nafter}, {frac:.2f}%)\n')
    #break #file

print(f'\n\033[1;33mSummary:\033[0m')
print(f'\n\033[33mEmpty input: {list_empty_input}\033[0m')
print(f'\n\033[31mEmpty output: {list_empty_output}\033[0m\n')
# Out:
# Loading file: tree_DYJetsToLL_M10to50.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_DYJetsToLL_M10to50.root (257->7, 2.72%)
#
#
# Loading file: tree_DYJetsToLL_M50.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_DYJetsToLL_M50.root (116185->686, 0.59%)
#
#
# Loading file: tree_EGamma_EGamma_A.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_EGamma_EGamma_A.root (65324->956, 1.46%)
#
#
# Loading file: tree_EGamma_EGamma_B.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_EGamma_EGamma_B.root (33016->461, 1.40%)
#
#
# Loading file: tree_EGamma_EGamma_C.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_EGamma_EGamma_C.root (32905->493, 1.50%)
#
#
# Loading file: tree_EGamma_EGamma_D.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_EGamma_EGamma_D.root (150874->2192, 1.45%)
#
#
# Loading file: tree_Higgs_bbH_HToZZTo4L.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_Higgs_bbH_HToZZTo4L.root (16078->122, 0.76%)
#
#
# Loading file: tree_Higgs_GluGluHToZZTo4L.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_Higgs_GluGluHToZZTo4L.root (31926->627, 1.96%)
#
#
# Loading file: tree_Higgs_GluGluToZH_HToZZTo4L.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_Higgs_GluGluToZH_HToZZTo4L.root (44878->4067, 9.06%)
#
#
# Loading file: tree_Higgs_GluGluZH_HToWW_ZTo2L.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_Higgs_GluGluZH_HToWW_ZTo2L.root (30098->6137, 20.39%)
#
#
# Loading file: tree_Higgs_ttHToNonbb.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_Higgs_ttHToNonbb.root (148491->12288, 8.28%)
#
#
# Loading file: tree_Higgs_VBF_HToZZTo4L.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_Higgs_VBF_HToZZTo4L.root (19422->842, 4.34%)
#
#
# Loading file: tree_Higgs_VHToNonbb.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_Higgs_VHToNonbb.root (9960->1272, 12.77%)
#
#
# Loading file: tree_HTbinnedWJets_100to200.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_HTbinnedWJets_100to200.root (5224->318, 6.09%)
#
#
# Loading file: tree_HTbinnedWJets_1200to2500.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_HTbinnedWJets_1200to2500.root (1836->149, 8.12%)
#
#
# Loading file: tree_HTbinnedWJets_200to400.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_HTbinnedWJets_200to400.root (8946->1251, 13.98%)
#
#
# Loading file: tree_HTbinnedWJets_2500toInf.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_HTbinnedWJets_2500toInf.root (702->9, 1.28%)
#
#
# Loading file: tree_HTbinnedWJets_400to600.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_HTbinnedWJets_400to600.root (1476->285, 19.31%)
#
#
# Loading file: tree_HTbinnedWJets_600to800.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_HTbinnedWJets_600to800.root (1812->281, 15.51%)
#
#
# Loading file: tree_HTbinnedWJets_70to100.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_HTbinnedWJets_70to100.root (4563->118, 2.59%)
#
#
# Loading file: tree_HTbinnedWJets_800to1200.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_HTbinnedWJets_800to1200.root (1912->250, 13.08%)
#
#
# Loading file: tree_QCD_EMEnriched_120to170.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_QCD_EMEnriched_120to170.root
#
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_QCD_EMEnriched_120to170.root (5->0, 0.00%)
#
#
# Loading file: tree_QCD_EMEnriched_170to300.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_QCD_EMEnriched_170to300.root
#
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_QCD_EMEnriched_170to300.root (2->0, 0.00%)
#
#
# Loading file: tree_QCD_EMEnriched_300toInf.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_QCD_EMEnriched_300toInf.root (3->1, 33.33%)
#
#
# Loading file: tree_QCD_EMEnriched_50to80.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_QCD_EMEnriched_50to80.root
#
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_QCD_EMEnriched_50to80.root (1->0, 0.00%)
#
#
# Loading file: tree_QCD_EMEnriched_80to120.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_QCD_EMEnriched_80to120.root
#
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_QCD_EMEnriched_80to120.root (3->0, 0.00%)
#
#
# Loading file: tree_QCD_MuEnriched_120to170.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_QCD_MuEnriched_120to170.root (255->1, 0.39%)
#
#
# Loading file: tree_QCD_MuEnriched_170to300.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_QCD_MuEnriched_170to300.root (456->1, 0.22%)
#
#
# Loading file: tree_QCD_MuEnriched_20to30.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_QCD_MuEnriched_20to30.root
#
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_QCD_MuEnriched_20to30.root (6->0, 0.00%)
#
#
# Loading file: tree_QCD_MuEnriched_300to470.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_QCD_MuEnriched_300to470.root (327->6, 1.83%)
#
#
# Loading file: tree_QCD_MuEnriched_30to50.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_QCD_MuEnriched_30to50.root
#
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_QCD_MuEnriched_30to50.root (80->0, 0.00%)
#
#
# Loading file: tree_QCD_MuEnriched_470to600.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_QCD_MuEnriched_470to600.root (206->4, 1.94%)
#
#
# Loading file: tree_QCD_MuEnriched_50to80.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_QCD_MuEnriched_50to80.root
#
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_QCD_MuEnriched_50to80.root (166->0, 0.00%)
#
#
# Loading file: tree_QCD_MuEnriched_600to800.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_QCD_MuEnriched_600to800.root (172->1, 0.58%)
#
#
# Loading file: tree_QCD_MuEnriched_800to1000.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_QCD_MuEnriched_800to1000.root (349->6, 1.72%)
#
#
# Loading file: tree_QCD_MuEnriched_80to120.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_QCD_MuEnriched_80to120.root (304->1, 0.33%)
#
#
# Loading file: tree_Rare_THQ.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_Rare_THQ.root (192828->15925, 8.26%)
#
#
# Loading file: tree_Rare_THW.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_Rare_THW.root (164172->26032, 15.86%)
#
#
# Loading file: tree_Rare_TTHH.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_Rare_TTHH.root (8605->352, 4.09%)
#
#
# Loading file: tree_Rare_TTTJ.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_Rare_TTTJ.root (11374->476, 4.18%)
#
#
# Loading file: tree_Rare_TTTT.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_Rare_TTTT.root (454648->12385, 2.72%)
#
#
# Loading file: tree_Rare_TTTW.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_Rare_TTTW.root (18158->899, 4.95%)
#
#
# Loading file: tree_Rare_TTWH.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_Rare_TTWH.root (14961->1039, 6.94%)
#
#
# Loading file: tree_Rare_TTWW.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_Rare_TTWW.root (34700->3839, 11.06%)
#
#
# Loading file: tree_Rare_TTWZ.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_Rare_TTWZ.root (12826->1309, 10.21%)
#
#
# Loading file: tree_Rare_TTZH.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_Rare_TTZH.root (7000->463, 6.61%)
#
#
# Loading file: tree_Rare_TTZZ.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_Rare_TTZZ.root (5088->453, 8.90%)
#
#
# Loading file: tree_Rare_tZq_ll.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_Rare_tZq_ll.root (312485->29318, 9.38%)
#
#
# Loading file: tree_SingleMuon_SingleMuon_A.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_SingleMuon_SingleMuon_A.root (30409->813, 2.67%)
#
#
# Loading file: tree_SingleMuon_SingleMuon_B.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_SingleMuon_SingleMuon_B.root (15910->427, 2.68%)
#
#
# Loading file: tree_SingleMuon_SingleMuon_C.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_SingleMuon_SingleMuon_C.root (16121->439, 2.72%)
#
#
# Loading file: tree_SingleMuon_SingleMuon_D.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_SingleMuon_SingleMuon_D.root (71444->2111, 2.95%)
#
#
# Loading file: tree_SingleTop_s-channel_LeptonDecays.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_SingleTop_s-channel_LeptonDecays.root (26009->377, 1.45%)
#
#
# Loading file: tree_SingleTop_t-channel_AntiTop_InclusiveDecays.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_SingleTop_t-channel_AntiTop_InclusiveDecays.root (33848->659, 1.95%)
#
#
# Loading file: tree_SingleTop_t-channel_Top_InclusiveDecays.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_SingleTop_t-channel_Top_InclusiveDecays.root (60775->1150, 1.89%)
#
#
# Loading file: tree_SingleTop_tW_AntiTop_InclusiveDecays.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_SingleTop_tW_AntiTop_InclusiveDecays.root (6101->338, 5.54%)
#
#
# Loading file: tree_SingleTop_tW_Top_InclusiveDecays.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_SingleTop_tW_Top_InclusiveDecays.root (6233->397, 6.37%)
#
#
# Loading file: tree_TTBar_TTTo2L2Nu.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_TTBar_TTTo2L2Nu.root (341764->21955, 6.42%)
#
#
# Loading file: tree_TTBar_TTToSemiLeptonic.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_TTBar_TTToSemiLeptonic.root (751163->37694, 5.02%)
#
#
# Loading file: tree_TTW_TTWToLNu.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_TTW_TTWToLNu.root (659302->78140, 11.85%)
#
#
# Loading file: tree_TTZ_TTZToLL.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_TTZ_TTZToLL.root (1298000->143610, 11.06%)
#
#
# Loading file: tree_VLLD_ele_M100.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLD_ele_M100.root (2809->282, 10.04%)
#
#
# Loading file: tree_VLLD_ele_M1000.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLD_ele_M1000.root (1128->579, 51.33%)
#
#
# Loading file: tree_VLLD_ele_M200.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLD_ele_M200.root (3196->1161, 36.33%)
#
#
# Loading file: tree_VLLD_ele_M300.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLD_ele_M300.root (1063->521, 49.01%)
#
#
# Loading file: tree_VLLD_ele_M400.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLD_ele_M400.root (1088->601, 55.24%)
#
#
# Loading file: tree_VLLD_ele_M600.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLD_ele_M600.root (1117->605, 54.16%)
#
#
# Loading file: tree_VLLD_ele_M800.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLD_ele_M800.root (1088->622, 57.17%)
#
#
# Loading file: tree_VLLD_mu_M100.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLD_mu_M100.root (3041->275, 9.04%)
#
#
# Loading file: tree_VLLD_mu_M200.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLD_mu_M200.root (1868->586, 31.37%)
#
#
# Loading file: tree_VLLD_mu_M300.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLD_mu_M300.root (562->257, 45.73%)
#
#
# Loading file: tree_VLLD_mu_M400.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLD_mu_M400.root (518->245, 47.30%)
#
#
# Loading file: tree_VLLD_mu_M600.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLD_mu_M600.root (473->258, 54.55%)
#
#
# Loading file: tree_VLLD_mu_M800.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLD_mu_M800.root (454->239, 52.64%)
#
#
# Loading file: tree_VLLS_ele_M100.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_ele_M100.root (802->77, 9.60%)
#
#
# Loading file: tree_VLLS_ele_M1000.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_ele_M1000.root (1218->672, 55.17%)
#
#
# Loading file: tree_VLLS_ele_M125.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_ele_M125.root (3179->538, 16.92%)
#
#
# Loading file: tree_VLLS_ele_M150.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_ele_M150.root (4576->977, 21.35%)
#
#
# Loading file: tree_VLLS_ele_M200.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_ele_M200.root (5912->2195, 37.13%)
#
#
# Loading file: tree_VLLS_ele_M250.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_ele_M250.root (5222->2281, 43.68%)
#
#
# Loading file: tree_VLLS_ele_M300.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_ele_M300.root (5529->2835, 51.28%)
#
#
# Loading file: tree_VLLS_ele_M350.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_ele_M350.root (2256->1257, 55.72%)
#
#
# Loading file: tree_VLLS_ele_M400.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_ele_M400.root (2399->1314, 54.77%)
#
#
# Loading file: tree_VLLS_ele_M450.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_ele_M450.root (2342->1351, 57.69%)
#
#
# Loading file: tree_VLLS_ele_M500.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_ele_M500.root (2355->1371, 58.22%)
#
#
# Loading file: tree_VLLS_ele_M750.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_ele_M750.root (1211->688, 56.81%)
#
#
# Loading file: tree_VLLS_mu_M100.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_mu_M100.root (851->76, 8.93%)
#
#
# Loading file: tree_VLLS_mu_M1000.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_mu_M1000.root (718->432, 60.17%)
#
#
# Loading file: tree_VLLS_mu_M125.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_mu_M125.root (3697->592, 16.01%)
#
#
# Loading file: tree_VLLS_mu_M150.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_mu_M150.root (4370->1008, 23.07%)
#
#
# Loading file: tree_VLLS_mu_M200.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_mu_M200.root (5077->1896, 37.34%)
#
#
# Loading file: tree_VLLS_mu_M250.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_mu_M250.root (4320->2090, 48.38%)
#
#
# Loading file: tree_VLLS_mu_M300.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_mu_M300.root (4456->2510, 56.33%)
#
#
# Loading file: tree_VLLS_mu_M400.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_mu_M400.root (1722->1083, 62.89%)
#
#
# Loading file: tree_VLLS_mu_M450.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_mu_M450.root (1648->1060, 64.32%)
#
#
# Loading file: tree_VLLS_mu_M500.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_mu_M500.root (1667->1027, 61.61%)
#
#
# Loading file: tree_VLLS_mu_M750.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_mu_M750.root (841->535, 63.61%)
#
#
# Loading file: tree_VLLS_tau_M100.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_tau_M100.root (1115->100, 8.97%)
#
#
# Loading file: tree_VLLS_tau_M125.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_tau_M125.root (2783->313, 11.25%)
#
#
# Loading file: tree_VLLS_tau_M150.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_tau_M150.root (3783->598, 15.81%)
#
#
# Loading file: tree_VLLS_tau_M200.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_tau_M200.root (4914->1223, 24.89%)
#
#
# Loading file: tree_VLLS_tau_M250.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_tau_M250.root (4467->1470, 32.91%)
#
#
# Loading file: tree_VLLS_tau_M300.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_tau_M300.root (4911->1814, 36.94%)
#
#
# Loading file: tree_VLLS_tau_M350.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_tau_M350.root (2008->800, 39.84%)
#
#
# Loading file: tree_VLLS_tau_M400.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_VLLS_tau_M400.root (2125->859, 40.42%)
#
#
# Loading file: tree_WGamma_WGToLNuG_01J.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_WGamma_WGToLNuG_01J.root (40553->3512, 8.66%)
#
#
# Loading file: tree_WpWp_WpWpJJEWK.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_WpWp_WpWpJJEWK.root (42583->13368, 31.39%)
#
#
# Loading file: tree_WpWp_WpWpJJQCD.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_WpWp_WpWpJJQCD.root (29266->8034, 27.45%)
#
#
# Loading file: tree_WWW_Inclusive.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_WWW_Inclusive.root (4232->1274, 30.10%)
#
#
# Loading file: tree_WWZ_Inclusive.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_WWZ_Inclusive.root (1134->325, 28.66%)
#
#
# Loading file: tree_WW_WWTo1L1Nu2Q.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_WW_WWTo1L1Nu2Q.root (4818->530, 11.00%)
#
#
# Loading file: tree_WW_WWTo2L2Nu.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_WW_WWTo2L2Nu.root (8042->927, 11.53%)
#
#
# Loading file: tree_WW_WWTo4Q.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_WW_WWTo4Q.root
#
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_WW_WWTo4Q.root (11->0, 0.00%)
#
#
# Loading file: tree_WZZ_Inclusive.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_WZZ_Inclusive.root (1667->421, 25.25%)
#
#
# Loading file: tree_WZ_WZTo1L1Nu2Q.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_WZ_WZTo1L1Nu2Q.root (1377->128, 9.30%)
#
#
# Loading file: tree_WZ_WZTo2L2Q.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_WZ_WZTo2L2Q.root (19454->579, 2.98%)
#
#
# Loading file: tree_WZ_WZTo3LNu.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_WZ_WZTo3LNu.root (338172->43229, 12.78%)
#
#
# Loading file: tree_ZGamma_ZGToLLG_01J.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_ZGamma_ZGToLLG_01J.root (45635->1103, 2.42%)
#
#
# Loading file: tree_ZZZ_Inclusive.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_ZZZ_Inclusive.root (448->82, 18.30%)
#
#
# Loading file: tree_ZZ_ZZTo2L2Nu.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_ZZ_ZZTo2L2Nu.root (34976->813, 2.32%)
#
#
# Loading file: tree_ZZ_ZZTo2Q2L.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_ZZ_ZZTo2Q2L.root (26323->573, 2.18%)
#
#
# Loading file: tree_ZZ_ZZTo2Q2Nu.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_ZZ_ZZTo2Q2Nu.root (28->1, 3.57%)
#
#
# Loading file: tree_ZZ_ZZTo4L.root
# File written: ../input_files/trees_modified/tree_2018UL_sr_Dec30/tree_ZZ_ZZTo4L.root (1471725->48935, 3.33%)
#
#
# Summary:
#
# Empty input: []
#
# Empty output: ['QCD_EMEnriched_120to170.root', 'QCD_EMEnriched_170to300.root', 'QCD_EMEnriched_50to80.root', 'QCD_EMEnriched_80to120.root', 'QCD_MuEnriched_20to30.root', 'QCD_MuEnriched_30to50.root', 'QCD_MuEnriched_50to80.root', 'WW_WWTo4Q.root']
#
# CPU times: user 2min 30s, sys: 15.9 s, total: 2min 46s
# Wall time: 3min 6s

# %% [markdown]
# ### Convert them into histograms

# %%
# %%time

run_here = False

channels = ['mm', 'me', 'em', 'ee']
for channel_ in channels:
    jobname_ = outjob
    campaign_ = campaign
    dump_ = outjob.replace('tree', 'hist')+'_'+channel_
    #command = f'python3 extractHistsFromTrees.py --jobname {jobname_} --dump {dump_} --channel {channel_} --campaign {campaign_}'
    arguments = f'extractHistsFromTrees.C("{jobname_}", "{dump_}", "{campaign_}", "{channel_}")'
    command = f"root -q -b -l '{arguments}'"
    print(f'\033[93m\nRunnning .. \n{command}\033[0m\n')

    if run_here: os.system(command)
    else: print('Run it yourself:')
    
print('Done!')
# Out:
# Runnning ..
# root -q -b -l 'extractHistsFromTrees.C("tree_2018UL_sr_Dec30", "hist_2018UL_sr_Dec30_mm", "2018_UL", "mm")'
#
# Run it yourself:
#
# Runnning ..
# root -q -b -l 'extractHistsFromTrees.C("tree_2018UL_sr_Dec30", "hist_2018UL_sr_Dec30_me", "2018_UL", "me")'
#
# Run it yourself:
#
# Runnning ..
# root -q -b -l 'extractHistsFromTrees.C("tree_2018UL_sr_Dec30", "hist_2018UL_sr_Dec30_em", "2018_UL", "em")'
#
# Run it yourself:
#
# Runnning ..
# root -q -b -l 'extractHistsFromTrees.C("tree_2018UL_sr_Dec30", "hist_2018UL_sr_Dec30_ee", "2018_UL", "ee")'
#
# Run it yourself:
# Done!
# CPU times: user 134 μs, sys: 0 ns, total: 134 μs
# Wall time: 128 μs
