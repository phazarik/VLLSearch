# %% [markdown]
# # Python based analysis
#
# This script takes trees as inputs and writes another sets of trees as outputs.<br>
# The trees are filtered in between.

# %%
import os, sys
import numpy as np
import uproot
import pandas as pd

# %%
#Global parameters

basedir = '../input_files/trees_modified'
injob  = 'tree_2018UL_baseline_Dec30'
outjob = 'tree_2018UL_topcr_Dec31'
campaign = '2018_UL'

indir = os.path.join(basedir, injob)
outdir = os.path.join(basedir, outjob)
os.makedirs(outdir, exist_ok=True)

# %%
def read_file_into_df(filepath):

    tfile = uproot.open(filepath)
    ttree = tfile['myEvents']
    branches = ttree.keys()
    awkarray = ttree.arrays(branches)
    df = pd.DataFrame(awkarray.to_list())

    #Not filtering by channels right now.
    #if 'channel' in df.columns: df = df[df['channel'] == channelno]       
    #print(f'dataframe for {sample} {subsample} loaded.')
    return df

def write_df_into_file(df, filepath):
    if df.empty:
        data_dict = {col: np.array([], dtype=df[col].dtype) for col in df.columns}
        print(f"\033[0;31mWarning: Writing empty file: {filepath}\033[0m\n")
    else:
        data_dict = df.to_dict('list')
        
    with uproot.recreate(filepath) as file: file['myEvents'] = data_dict
    
print('Functions loaded.')
# Out:
# Functions loaded.

# %%
# %%time

list_of_files = os.listdir(indir)
list_empty_input = []
list_empty_output = []

for f in list_of_files:

    #if 'SingleMuon' not in f: continue

    #Step1: Prepare the dataframe
    print(f'\nLoading file: {f}')
    filepath = os.path.join(indir, f)
    sample = f.split("_")[1]
    subsample = "_".join(f.split("_")[2:])
       
    outfile = os.path.join(outdir, f)
    #if os.path.exists(outfile): continue
    #if 'WJets' not in f: continue

    df = read_file_into_df(filepath)
    if df.empty : 
        print(f"\033[0;31mWarning: Empty input file: {filepath}\033[0m\n")
        list_empty_input.append(filepath)

    #Creating working points on the dataframe using the NN.
    df['flag_qcd'] = (
        ((df['channel'].isin([0, 1])) & (df['nnscore_qcd_vlldmu_200_800']  < 0.30)) |
        ((df['channel'].isin([2, 3])) & (df['nnscore_qcd_vlldele_200_800'] < 0.30))
    )

    df['flag_topregion'] = (
        ((df['channel'].isin([0, 1])) & (df['nnscore_qcd_vlldmu_200_800']  > 0.50) & (df['nnscore_qcd_vlldmu_200_800']  < 0.70)) |
        ((df['channel'].isin([2, 3])) & (df['nnscore_qcd_vlldmu_200_800']  > 0.50) & (df['nnscore_qcd_vlldele_200_800'] < 0.70))
    )
    
    df['flag_searchregion'] = (
        ((df['channel'].isin([0, 1])) & (df['nnscore_qcd_vlldmu_200_800']  > 0.70)) |
        ((df['channel'].isin([2, 3])) & (df['nnscore_qcd_vlldele_200_800'] > 0.70))
    )

    # Put any cuts here on dataframe as you like
    # Define conditions as strings
    dy_veto = 'not (channel == 3 and 76 < dilep_mass < 106)'

    #Step1: Controlling QCD:
    qcd_cr = f'{dy_veto} and flag_qcd and 0.02<lep0_iso<0.15 and lep0_sip3d>5'
    qcd_vr = f'{dy_veto} and flag_qcd and 0.02<lep0_iso<0.15 and lep0_sip3d<5'

    #Step2: Controlling Drell-Yan:
    dycr  = f'76<dilep_mass<106  and dilep_ptratio > 0.7'

    tight_sip3d =  'lep0_sip3d<5 and lep1_sip3d<10'
    qcd_veto = f'{tight_sip3d} and {dy_veto} and not flag_qcd and HT>50'

    #Step3: Controlling TTbar:
    top_cr = f'{qcd_veto} and flag_topregion'
    top_vr = f'{qcd_veto} and flag_searchregion and nbjet>0'

    #Step5: Signal regions:
    sig_region = f'{qcd_veto} and flag_searchregion and nbjet == 0'
    
    #------------------------------
    # Final event selection:
    event_selection = top_cr
    #------------------------------

    # Use df.query with the combined condition
    df_filtered = df.query(event_selection)
    
    if df_filtered.empty: list_empty_output.append(f'{sample}_{subsample}')

    nbefore = len(df)
    nafter = len(df_filtered)

    frac = 0
    if nbefore != 0: frac = nafter*100/nbefore

    #display(df_filtered)

    write_df_into_file(df_filtered, outfile)
    print(f'\033[1;32mFile written: {outfile}\033[0m ({nbefore}->{nafter}, {frac:.2f}%)\n')
    #break #file

print(f'\n\033[1;33mSummary:\033[0m')
print(f'\n\033[33mEmpty input: {list_empty_input}\033[0m')
print(f'\n\033[31mEmpty output: {list_empty_output}\033[0m\n')
# Out:
# Loading file: tree_DYJetsToLL_M10to50.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_DYJetsToLL_M10to50.root
#
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_DYJetsToLL_M10to50.root (257->0, 0.00%)
#
#
# Loading file: tree_DYJetsToLL_M50.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_DYJetsToLL_M50.root (116185->111, 0.10%)
#
#
# Loading file: tree_EGamma_EGamma_A.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_EGamma_EGamma_A.root (65324->173, 0.26%)
#
#
# Loading file: tree_EGamma_EGamma_B.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_EGamma_EGamma_B.root (33016->72, 0.22%)
#
#
# Loading file: tree_EGamma_EGamma_C.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_EGamma_EGamma_C.root (32905->74, 0.22%)
#
#
# Loading file: tree_EGamma_EGamma_D.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_EGamma_EGamma_D.root (150874->335, 0.22%)
#
#
# Loading file: tree_Higgs_bbH_HToZZTo4L.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_Higgs_bbH_HToZZTo4L.root (16078->108, 0.67%)
#
#
# Loading file: tree_Higgs_GluGluHToZZTo4L.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_Higgs_GluGluHToZZTo4L.root (31926->235, 0.74%)
#
#
# Loading file: tree_Higgs_GluGluToZH_HToZZTo4L.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_Higgs_GluGluToZH_HToZZTo4L.root (44878->1351, 3.01%)
#
#
# Loading file: tree_Higgs_GluGluZH_HToWW_ZTo2L.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_Higgs_GluGluZH_HToWW_ZTo2L.root (30098->1220, 4.05%)
#
#
# Loading file: tree_Higgs_ttHToNonbb.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_Higgs_ttHToNonbb.root (148491->10842, 7.30%)
#
#
# Loading file: tree_Higgs_VBF_HToZZTo4L.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_Higgs_VBF_HToZZTo4L.root (19422->348, 1.79%)
#
#
# Loading file: tree_Higgs_VHToNonbb.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_Higgs_VHToNonbb.root (9960->377, 3.79%)
#
#
# Loading file: tree_HTbinnedWJets_100to200.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_HTbinnedWJets_100to200.root (5224->116, 2.22%)
#
#
# Loading file: tree_HTbinnedWJets_1200to2500.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_HTbinnedWJets_1200to2500.root (1836->19, 1.03%)
#
#
# Loading file: tree_HTbinnedWJets_200to400.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_HTbinnedWJets_200to400.root (8946->341, 3.81%)
#
#
# Loading file: tree_HTbinnedWJets_2500toInf.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_HTbinnedWJets_2500toInf.root (702->3, 0.43%)
#
#
# Loading file: tree_HTbinnedWJets_400to600.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_HTbinnedWJets_400to600.root (1476->52, 3.52%)
#
#
# Loading file: tree_HTbinnedWJets_600to800.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_HTbinnedWJets_600to800.root (1812->53, 2.92%)
#
#
# Loading file: tree_HTbinnedWJets_70to100.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_HTbinnedWJets_70to100.root (4563->42, 0.92%)
#
#
# Loading file: tree_HTbinnedWJets_800to1200.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_HTbinnedWJets_800to1200.root (1912->43, 2.25%)
#
#
# Loading file: tree_QCD_EMEnriched_120to170.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_QCD_EMEnriched_120to170.root (5->1, 20.00%)
#
#
# Loading file: tree_QCD_EMEnriched_170to300.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_QCD_EMEnriched_170to300.root
#
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_QCD_EMEnriched_170to300.root (2->0, 0.00%)
#
#
# Loading file: tree_QCD_EMEnriched_300toInf.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_QCD_EMEnriched_300toInf.root
#
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_QCD_EMEnriched_300toInf.root (3->0, 0.00%)
#
#
# Loading file: tree_QCD_EMEnriched_50to80.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_QCD_EMEnriched_50to80.root
#
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_QCD_EMEnriched_50to80.root (1->0, 0.00%)
#
#
# Loading file: tree_QCD_EMEnriched_80to120.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_QCD_EMEnriched_80to120.root
#
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_QCD_EMEnriched_80to120.root (3->0, 0.00%)
#
#
# Loading file: tree_QCD_MuEnriched_120to170.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_QCD_MuEnriched_120to170.root (255->2, 0.78%)
#
#
# Loading file: tree_QCD_MuEnriched_170to300.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_QCD_MuEnriched_170to300.root (456->5, 1.10%)
#
#
# Loading file: tree_QCD_MuEnriched_20to30.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_QCD_MuEnriched_20to30.root
#
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_QCD_MuEnriched_20to30.root (6->0, 0.00%)
#
#
# Loading file: tree_QCD_MuEnriched_300to470.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_QCD_MuEnriched_300to470.root (327->2, 0.61%)
#
#
# Loading file: tree_QCD_MuEnriched_30to50.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_QCD_MuEnriched_30to50.root
#
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_QCD_MuEnriched_30to50.root (80->0, 0.00%)
#
#
# Loading file: tree_QCD_MuEnriched_470to600.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_QCD_MuEnriched_470to600.root (206->1, 0.49%)
#
#
# Loading file: tree_QCD_MuEnriched_50to80.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_QCD_MuEnriched_50to80.root
#
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_QCD_MuEnriched_50to80.root (166->0, 0.00%)
#
#
# Loading file: tree_QCD_MuEnriched_600to800.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_QCD_MuEnriched_600to800.root (172->2, 1.16%)
#
#
# Loading file: tree_QCD_MuEnriched_800to1000.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_QCD_MuEnriched_800to1000.root (349->1, 0.29%)
#
#
# Loading file: tree_QCD_MuEnriched_80to120.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_QCD_MuEnriched_80to120.root
#
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_QCD_MuEnriched_80to120.root (304->0, 0.00%)
#
#
# Loading file: tree_Rare_THQ.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_Rare_THQ.root (192828->11496, 5.96%)
#
#
# Loading file: tree_Rare_THW.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_Rare_THW.root (164172->12001, 7.31%)
#
#
# Loading file: tree_Rare_TTHH.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_Rare_TTHH.root (8605->664, 7.72%)
#
#
# Loading file: tree_Rare_TTTJ.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_Rare_TTTJ.root (11374->899, 7.90%)
#
#
# Loading file: tree_Rare_TTTT.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_Rare_TTTT.root (454648->35505, 7.81%)
#
#
# Loading file: tree_Rare_TTTW.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_Rare_TTTW.root (18158->1424, 7.84%)
#
#
# Loading file: tree_Rare_TTWH.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_Rare_TTWH.root (14961->1149, 7.68%)
#
#
# Loading file: tree_Rare_TTWW.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_Rare_TTWW.root (34700->2750, 7.93%)
#
#
# Loading file: tree_Rare_TTWZ.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_Rare_TTWZ.root (12826->919, 7.17%)
#
#
# Loading file: tree_Rare_TTZH.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_Rare_TTZH.root (7000->474, 6.77%)
#
#
# Loading file: tree_Rare_TTZZ.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_Rare_TTZZ.root (5088->334, 6.56%)
#
#
# Loading file: tree_Rare_tZq_ll.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_Rare_tZq_ll.root (312485->15185, 4.86%)
#
#
# Loading file: tree_SingleMuon_SingleMuon_A.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_SingleMuon_SingleMuon_A.root (30409->533, 1.75%)
#
#
# Loading file: tree_SingleMuon_SingleMuon_B.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_SingleMuon_SingleMuon_B.root (15910->274, 1.72%)
#
#
# Loading file: tree_SingleMuon_SingleMuon_C.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_SingleMuon_SingleMuon_C.root (16121->306, 1.90%)
#
#
# Loading file: tree_SingleMuon_SingleMuon_D.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_SingleMuon_SingleMuon_D.root (71444->1317, 1.84%)
#
#
# Loading file: tree_SingleTop_s-channel_LeptonDecays.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_SingleTop_s-channel_LeptonDecays.root (26009->517, 1.99%)
#
#
# Loading file: tree_SingleTop_t-channel_AntiTop_InclusiveDecays.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_SingleTop_t-channel_AntiTop_InclusiveDecays.root (33848->698, 2.06%)
#
#
# Loading file: tree_SingleTop_t-channel_Top_InclusiveDecays.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_SingleTop_t-channel_Top_InclusiveDecays.root (60775->1245, 2.05%)
#
#
# Loading file: tree_SingleTop_tW_AntiTop_InclusiveDecays.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_SingleTop_tW_AntiTop_InclusiveDecays.root (6101->187, 3.07%)
#
#
# Loading file: tree_SingleTop_tW_Top_InclusiveDecays.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_SingleTop_tW_Top_InclusiveDecays.root (6233->227, 3.64%)
#
#
# Loading file: tree_TTBar_TTTo2L2Nu.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_TTBar_TTTo2L2Nu.root (341764->11298, 3.31%)
#
#
# Loading file: tree_TTBar_TTToSemiLeptonic.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_TTBar_TTToSemiLeptonic.root (751163->29580, 3.94%)
#
#
# Loading file: tree_TTW_TTWToLNu.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_TTW_TTWToLNu.root (659302->47628, 7.22%)
#
#
# Loading file: tree_TTZ_TTZToLL.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_TTZ_TTZToLL.root (1298000->84761, 6.53%)
#
#
# Loading file: tree_VLLD_ele_M100.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLD_ele_M100.root (2809->99, 3.52%)
#
#
# Loading file: tree_VLLD_ele_M1000.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLD_ele_M1000.root (1128->24, 2.13%)
#
#
# Loading file: tree_VLLD_ele_M200.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLD_ele_M200.root (3196->93, 2.91%)
#
#
# Loading file: tree_VLLD_ele_M300.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLD_ele_M300.root (1063->28, 2.63%)
#
#
# Loading file: tree_VLLD_ele_M400.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLD_ele_M400.root (1088->22, 2.02%)
#
#
# Loading file: tree_VLLD_ele_M600.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLD_ele_M600.root (1117->22, 1.97%)
#
#
# Loading file: tree_VLLD_ele_M800.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLD_ele_M800.root (1088->19, 1.75%)
#
#
# Loading file: tree_VLLD_mu_M100.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLD_mu_M100.root (3041->143, 4.70%)
#
#
# Loading file: tree_VLLD_mu_M200.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLD_mu_M200.root (1868->125, 6.69%)
#
#
# Loading file: tree_VLLD_mu_M300.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLD_mu_M300.root (562->24, 4.27%)
#
#
# Loading file: tree_VLLD_mu_M400.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLD_mu_M400.root (518->33, 6.37%)
#
#
# Loading file: tree_VLLD_mu_M600.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLD_mu_M600.root (473->21, 4.44%)
#
#
# Loading file: tree_VLLD_mu_M800.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLD_mu_M800.root (454->26, 5.73%)
#
#
# Loading file: tree_VLLS_ele_M100.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_ele_M100.root (802->16, 2.00%)
#
#
# Loading file: tree_VLLS_ele_M1000.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_ele_M1000.root (1218->17, 1.40%)
#
#
# Loading file: tree_VLLS_ele_M125.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_ele_M125.root (3179->78, 2.45%)
#
#
# Loading file: tree_VLLS_ele_M150.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_ele_M150.root (4576->99, 2.16%)
#
#
# Loading file: tree_VLLS_ele_M200.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_ele_M200.root (5912->135, 2.28%)
#
#
# Loading file: tree_VLLS_ele_M250.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_ele_M250.root (5222->91, 1.74%)
#
#
# Loading file: tree_VLLS_ele_M300.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_ele_M300.root (5529->92, 1.66%)
#
#
# Loading file: tree_VLLS_ele_M350.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_ele_M350.root (2256->36, 1.60%)
#
#
# Loading file: tree_VLLS_ele_M400.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_ele_M400.root (2399->43, 1.79%)
#
#
# Loading file: tree_VLLS_ele_M450.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_ele_M450.root (2342->29, 1.24%)
#
#
# Loading file: tree_VLLS_ele_M500.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_ele_M500.root (2355->36, 1.53%)
#
#
# Loading file: tree_VLLS_ele_M750.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_ele_M750.root (1211->15, 1.24%)
#
#
# Loading file: tree_VLLS_mu_M100.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_mu_M100.root (851->19, 2.23%)
#
#
# Loading file: tree_VLLS_mu_M1000.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_mu_M1000.root (718->13, 1.81%)
#
#
# Loading file: tree_VLLS_mu_M125.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_mu_M125.root (3697->122, 3.30%)
#
#
# Loading file: tree_VLLS_mu_M150.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_mu_M150.root (4370->205, 4.69%)
#
#
# Loading file: tree_VLLS_mu_M200.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_mu_M200.root (5077->302, 5.95%)
#
#
# Loading file: tree_VLLS_mu_M250.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_mu_M250.root (4320->247, 5.72%)
#
#
# Loading file: tree_VLLS_mu_M300.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_mu_M300.root (4456->220, 4.94%)
#
#
# Loading file: tree_VLLS_mu_M400.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_mu_M400.root (1722->64, 3.72%)
#
#
# Loading file: tree_VLLS_mu_M450.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_mu_M450.root (1648->53, 3.22%)
#
#
# Loading file: tree_VLLS_mu_M500.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_mu_M500.root (1667->61, 3.66%)
#
#
# Loading file: tree_VLLS_mu_M750.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_mu_M750.root (841->27, 3.21%)
#
#
# Loading file: tree_VLLS_tau_M100.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_tau_M100.root (1115->10, 0.90%)
#
#
# Loading file: tree_VLLS_tau_M125.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_tau_M125.root (2783->63, 2.26%)
#
#
# Loading file: tree_VLLS_tau_M150.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_tau_M150.root (3783->110, 2.91%)
#
#
# Loading file: tree_VLLS_tau_M200.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_tau_M200.root (4914->207, 4.21%)
#
#
# Loading file: tree_VLLS_tau_M250.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_tau_M250.root (4467->194, 4.34%)
#
#
# Loading file: tree_VLLS_tau_M300.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_tau_M300.root (4911->185, 3.77%)
#
#
# Loading file: tree_VLLS_tau_M350.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_tau_M350.root (2008->58, 2.89%)
#
#
# Loading file: tree_VLLS_tau_M400.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_VLLS_tau_M400.root (2125->84, 3.95%)
#
#
# Loading file: tree_WGamma_WGToLNuG_01J.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_WGamma_WGToLNuG_01J.root (40553->700, 1.73%)
#
#
# Loading file: tree_WpWp_WpWpJJEWK.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_WpWp_WpWpJJEWK.root (42583->2354, 5.53%)
#
#
# Loading file: tree_WpWp_WpWpJJQCD.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_WpWp_WpWpJJQCD.root (29266->1719, 5.87%)
#
#
# Loading file: tree_WWW_Inclusive.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_WWW_Inclusive.root (4232->240, 5.67%)
#
#
# Loading file: tree_WWZ_Inclusive.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_WWZ_Inclusive.root (1134->61, 5.38%)
#
#
# Loading file: tree_WW_WWTo1L1Nu2Q.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_WW_WWTo1L1Nu2Q.root (4818->142, 2.95%)
#
#
# Loading file: tree_WW_WWTo2L2Nu.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_WW_WWTo2L2Nu.root (8042->91, 1.13%)
#
#
# Loading file: tree_WW_WWTo4Q.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_WW_WWTo4Q.root
#
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_WW_WWTo4Q.root (11->0, 0.00%)
#
#
# Loading file: tree_WZZ_Inclusive.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_WZZ_Inclusive.root (1667->92, 5.52%)
#
#
# Loading file: tree_WZ_WZTo1L1Nu2Q.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_WZ_WZTo1L1Nu2Q.root (1377->37, 2.69%)
#
#
# Loading file: tree_WZ_WZTo2L2Q.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_WZ_WZTo2L2Q.root (19454->116, 0.60%)
#
#
# Loading file: tree_WZ_WZTo3LNu.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_WZ_WZTo3LNu.root (338172->9138, 2.70%)
#
#
# Loading file: tree_ZGamma_ZGToLLG_01J.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_ZGamma_ZGToLLG_01J.root (45635->150, 0.33%)
#
#
# Loading file: tree_ZZZ_Inclusive.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_ZZZ_Inclusive.root (448->11, 2.46%)
#
#
# Loading file: tree_ZZ_ZZTo2L2Nu.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_ZZ_ZZTo2L2Nu.root (34976->43, 0.12%)
#
#
# Loading file: tree_ZZ_ZZTo2Q2L.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_ZZ_ZZTo2Q2L.root (26323->177, 0.67%)
#
#
# Loading file: tree_ZZ_ZZTo2Q2Nu.root
# Warning: Writing empty file: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_ZZ_ZZTo2Q2Nu.root
#
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_ZZ_ZZTo2Q2Nu.root (28->0, 0.00%)
#
#
# Loading file: tree_ZZ_ZZTo4L.root
# File written: ../input_files/trees_modified/tree_2018UL_topcr_Dec31/tree_ZZ_ZZTo4L.root (1471725->12120, 0.82%)
#
#
# Summary:
#
# Empty input: []
#
# Empty output: ['DYJetsToLL_M10to50.root', 'QCD_EMEnriched_170to300.root', 'QCD_EMEnriched_300toInf.root', 'QCD_EMEnriched_50to80.root', 'QCD_EMEnriched_80to120.root', 'QCD_MuEnriched_20to30.root', 'QCD_MuEnriched_30to50.root', 'QCD_MuEnriched_50to80.root', 'QCD_MuEnriched_80to120.root', 'WW_WWTo4Q.root', 'ZZ_ZZTo2Q2Nu.root']
#
# CPU times: user 2min 30s, sys: 18 s, total: 2min 48s
# Wall time: 3min 10s

# %% [markdown]
# ### Convert them into histograms

# %%
# %%time

run_here = False

channels = ['mm', 'me', 'em', 'ee']
for channel_ in channels:
    jobname_ = outjob
    campaign_ = campaign
    dump_ = outjob.replace('tree', 'hist')+'_'+channel_
    arguments = f'extractHistsFromTrees.C("{jobname_}", "{dump_}", "{campaign_}", "{channel_}")'
    command = f"root -q -b -l '{arguments}'"
    print(f'\033[93m\nRunnning .. \n{command}\033[0m\n')

    if run_here: os.system(command)
    else: print('Run it yourself:')
    
print('Done!')
# Out:
# Runnning ..
# root -q -b -l 'extractHistsFromTrees.C("tree_2018UL_topcr_Dec31", "hist_2018UL_topcr_Dec31_mm", "2018_UL", "mm")'
#
# Run it yourself:
#
# Runnning ..
# root -q -b -l 'extractHistsFromTrees.C("tree_2018UL_topcr_Dec31", "hist_2018UL_topcr_Dec31_me", "2018_UL", "me")'
#
# Run it yourself:
#
# Runnning ..
# root -q -b -l 'extractHistsFromTrees.C("tree_2018UL_topcr_Dec31", "hist_2018UL_topcr_Dec31_em", "2018_UL", "em")'
#
# Run it yourself:
#
# Runnning ..
# root -q -b -l 'extractHistsFromTrees.C("tree_2018UL_topcr_Dec31", "hist_2018UL_topcr_Dec31_ee", "2018_UL", "ee")'
#
# Run it yourself:
# Done!
# CPU times: user 221 μs, sys: 26 μs, total: 247 μs
# Wall time: 236 μs
